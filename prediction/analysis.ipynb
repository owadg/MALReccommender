# %%
import gzip
from datetime import datetime
from collections import defaultdict
import math
import scipy
import scipy.optimize
from sklearn import svm
from sklearn import metrics
import numpy as np
import string
import random
import string
import json
import time
from datetime import timedelta
import requests
import re
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.feature_extraction.text import TfidfVectorizer
import xlearn as xl

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
def readCSV(path):
    #user,id,start_date,end_date,score,num_episodes_watched,status
    #status encoding: watching = 0, completed = 1, on_hold = 2, dropped = 3, plan_to_watch = 4
    f = open(path, 'r')
    
    for l in f:
        user,anime_id,start_date,end_date,score,num_episodes_watched,status = l.strip().split(',')
        anime_id=int(anime_id)
        score=int(score)
        num_episodes_watched=int(num_episodes_watched)
        status = int(status)
        yield user,anime_id,start_date,end_date,score,num_episodes_watched,status

# %%
#Get API KEY in case we need it
file = open("../data/mal_client_id.txt", 'r')
clientID = file.read()
file.close()

# %%
#our user data set
completed_with_date = []

for i in readCSV('../data/user_animelist_details_16mil.txt'):
    if (i[6] == 1 and i[3] != "" and i[4] != 0):
        completed_with_date.append(i)
random.shuffle(completed_with_date)

#our item data set
file = open("../data/anime_list_details.json", 'r')
animelist = json.loads(file.read())
animelistdict = dict()
for record in animelist:
    animelistdict[record['id']] = {}
    for key in record:
        #we don't need to use this key again
        if key == 'id':
            continue
        animelistdict[record['id']][key] = record[key]

# %%
#for simpler reccommender
X = [(entry[0], int(entry[1]), entry[3]) for entry in completed_with_date]
Y = [int(entry[4]) for entry in completed_with_date]
#dividing up dataset
XTrain = X[:len(X)//2]
XValid = X[len(X)//2:len(X)*3//4]
XTest = X[len(X)*3//4:]
YTrain = Y[:len(Y)//2]
YValid = Y[len(Y)//2:len(Y)*3//4]
YTest = Y[len(Y)*3//4:]

# %%
#data we are getting from our scored subset
scoresPerAnime = defaultdict(list)
scoresPerUser = defaultdict(list)
usersPerAnime = defaultdict(set)
animePerUser = defaultdict(set)
ratingsDict = defaultdict(list)

#changing this to be Xtrain!! - used to be userData
for index in range(len(XTrain)):
    i = XTrain[index]
    ratingsDict[(i[0],i[1])] = int(YTrain[index])
    scoresPerAnime[i[1]].append(int(YTrain[index]))
    scoresPerUser[i[0]].append(int(YTrain[index]))
    usersPerAnime[i[1]].add(i[0])
    animePerUser[i[0]].add(i[1])

# %%
#average score per anime
averageScorePerAnime = defaultdict(list)
for anime in scoresPerAnime:
    averageScorePerAnime[anime] = sum(scoresPerAnime[anime])/len(scoresPerAnime[anime])

# %%
numTests = 50000

# %%
#cache
pearsondict = dict()

# Between two items
def Pearson (i1 , i2):
    #for cache! this should hugely increase performance
    if (i1,i2) in pearsondict:
        return pearsondict[(i1,i2)]
    elif (i2,i1) in pearsondict:
        return pearsondict[(i2,i1)]
    
    #first we check if we have info on these
    if i1 not in scoresPerAnime or i2 not in scoresPerAnime:
        return 0
    
    #averages
    if len(scoresPerAnime[i1]) > 0 and len(scoresPerAnime[i2]) > 0:
        i1avg = averageScorePerAnime[i1]
        i2avg = averageScorePerAnime[i2]
    else:
        return 0
    
    #at this point, we know we have valid keys and we know that we have averages
    #now we just need to compute
    num = []
    denom1 = []
    denom2 = []
    for commonUser in usersPerAnime[i1].intersection(usersPerAnime[i2]):
        #if the sets are disjoint, we can just remove them, lol!
        if usersPerAnime[i1].isdisjoint(usersPerAnime[i2]):
            continue
            
        #num term
        num.append((ratingsDict[(commonUser,i1)] - i1avg) * (ratingsDict[(commonUser,i2)] - i2avg))
        
        #denom term 1
        denom1.append((ratingsDict[(commonUser,i1)] - i1avg)**2)
        
        #denom term 2
        denom2.append((ratingsDict[(commonUser,i2)] - i2avg)**2)
        
    #let's put it together
    num = sum(num)
    denom1 = sum(denom1)
    denom2 = sum(denom2)
    if denom1 == 0 or denom2 == 0:
        return 0
    pearson = num / (denom1 * denom2)
    
    #cache answer, then return it
    pearsondict[(i1, i2)] = pearson
    pearsondict[(i2, i1)] = pearson
    
    return pearson

# %%
#we train a linear regressor to fit a cubic equation to the timestamps.
#we generate a sub dataset, LOL. There will be no evaluation on this, except how well it works in the model
#the features will be number of days/1000 since first review date = x -> c + x + x^2 + x^3
startDate = datetime.strptime('1988-01-01', '%Y-%m-%d')

timeX = []
timeY = []
for i in range(len(XTrain)):
    timestamp = Xtrain[i][2]
    
    timearr = []
    #some date data is in a different format, can tell by length
    if(len(timestamp) == 10):
        tempDate = datetime.strptime(timestamp,'%Y-%m-%d')
    elif (len(timestamp) == 4):
        tempDate = datetime.strptime(timestamp,'%Y')
    elif (len(timestamp) == 7):
        tempDate = datetime.strptime(timestamp,'%Y-%m')
    else:
        #we don't know the date so we toss it
        continue
    # let's throw it out if its before our startDate
    if  tempDate < startDate:
        continue
        
    #now, let's get the time delta
    timeDelta = tempDate - startDate
    days = timeDelta.total_seconds() /(60 * 60 * 24)
    #normalizing it a bit...
    days = days/1000
    
    #here is our feature representation
    timeX.append([1, days, days**2, days**3])
    timeY.append(YTrain[i])

# %%
model = linear_model.LinearRegression(fit_intercept=False)
model.fit(timeX, timeY)
# Out:
# LinearRegression(fit_intercept=False)

# %%
weights = model.coef_
weights
# Out:
# array([ 8.32061145e+00, -6.68369365e-02,  3.91325354e-04, -4.06757756e-07])

# %%
def timestampWeight(timestamp):
    #some date data is in a different format, can tell by length
    if(len(timestamp) == 10):
        tempDate = datetime.strptime(timestamp,'%Y-%m-%d')
    elif (len(timestamp) == 4):
        tempDate = datetime.strptime(timestamp,'%Y')
    elif (len(timestamp) == 7):
        tempDate = datetime.strptime(timestamp,'%Y-%m')
    else:
        #we don't know the date so we toss it
        return 0
    # let's throw it out if its before our startDate, cuz its usually malformed
    if  tempDate < startDate:
        return 0
        
    #now, let's get the time delta
    timeDelta = tempDate - startDate
    days = timeDelta.total_seconds() /(60 * 60 * 24)
    #normalizing it a bit...
    days = days/1000
    #return weights[0] + weights[1]*days + weights[0]*days**2 + weights[0]*days**3
    return math.e**(days)

# %%
def predict(username, animeid, timestamp):
    denom = []
    ratingsForNum = []
    for anime in animePerUser[username]:
        #we cannot consider this exact task if we have it stored somewhere
        if anime == animeid:
            next
        ratingsForNum.append(ratingsDict[username,anime])
        denom.append(Pearson(animeid, anime) * timestampWeight(timestamp))
    num = [ratingsForNum[i] * denom[i] for i in range(len(denom))]
    #sometimes this will happen, especially for niche anime. let's just return the average score...
    if sum(denom) == 0:
        if animeid in averageScorePerAnime:
            return averageScorePerAnime[animeid]
        elif animeid in animelistdict and 'mean' in animelistdict[animeid]:
            return animelistdict[animeid]['mean']
        else:
            return 5
    #let's just project this into our output zone too
    result = sum(num)/sum(denom)
    if result > 10:
        result = 10
    elif result < 0:
        result = 0
    return result

# %%
def predictMultiple(X):
    yPred = []
    for i in X:
        yPred.append(predict(i[0], i[1], i[2]))
    return yPred

# %%
# %%time
yPred = predictMultiple(XValid[:numTests])
metrics.mean_squared_error(YValid[:numTests], yPred, squared= False)
# Out:
# CPU times: user 1min 22s, sys: 6.68 ms, total: 1min 22s
# Wall time: 1min 22s
# 2.207905278370655

# %%
def predictNonTemporal(username, animeid, timestamp):
    denom = []
    ratingsForNum = []
    for anime in animePerUser[username]:
        #we cannot consider this exact task if we have it stored somewhere
        if anime == animeid:
            next
        ratingsForNum.append(ratingsDict[username,anime])
        denom.append(Pearson(animeid, anime))
    num = [ratingsForNum[i] * denom[i] for i in range(len(denom))]
    #sometimes this will happen, especially for niche anime. let's just return the average score...
    if sum(denom) == 0:
        if animeid in averageScorePerAnime:
            return averageScorePerAnime[animeid]
        elif animeid in animelistdict and 'mean' in animelistdict[animeid]:
            return animelistdict[animeid]['mean']
        else:
            return 5
    #let's just project this into our output zone too
    result = sum(num)/sum(denom)
    if result > 10:
        result = 10
    elif result < 0:
        result = 0
    return result

# %%
def predictMultipleNonTemporal(X):
    yPred = []
    for i in X:
        yPred.append(predictNonTemporal(i[0], i[1], i[2]))
    return yPred

# %%
# %%time
yPred = predictMultipleNonTemporal(XValid[:numTests])
metrics.mean_squared_error(YValid[:numTests], yPred, squared= False)
# Out:
# CPU times: user 14.1 s, sys: 15 µs, total: 14.1 s
# Wall time: 14.1 s
# 2.2100237749944793

# %%
def predictAverageScoreForAnime(username, animeid, timestamp):
    if animeid in averageScorePerAnime:
        return averageScorePerAnime[animeid]
    elif animeid in animelistdict and 'mean' in animelistdict[animeid]:
        return animelistdict[animeid]['mean']
    else:
        return 5

# %%
def predictMultipleAverageScoreForAnime(X):
    yPred = []
    for i in X:
        yPred.append(predictAverageScoreForAnime(i[0], i[1], i[2]))
    return yPred

# %%
# %%time
yPred = predictMultipleAverageScoreForAnime(XValid[:numTests])
metrics.mean_squared_error(YValid[:numTests], yPred, squared= False)
# Out:
# CPU times: user 33.2 ms, sys: 0 ns, total: 33.2 ms
# Wall time: 32.9 ms
# 1.4260072270892707

# %%
def predictAverageScoreForUser(username, animeid, timestamp):
    if username in scoresPerUser:
        return sum(scoresPerUser[username])/len(scoresPerUser[username])
    elif animeid in averageScorePerAnime:
        return averageScorePerAnime[animeid]
    elif animeid in animelistdict and 'mean' in animelistdict[animeid]:
        return animelistdict[animeid]['mean']
    else:
        return 5

# %%
def predictMultipleAverageScoreForUser(X):
    yPred = []
    for i in X:
        yPred.append(predictAverageScoreForUser(i[0], i[1], i[2]))
    return yPred

# %%
# %%time
yPred = predictMultipleAverageScoreForUser(XValid[:numTests])
metrics.mean_squared_error(YValid[:numTests], yPred, squared= False)
# Out:
# CPU times: user 121 ms, sys: 3 µs, total: 121 ms
# Wall time: 120 ms
# 1.3617474788832709

# %%
#######################
## OLD VER           ##
#######################
#data we are getting from our scored subset
scoresPerAnime = defaultdict(list)
scoresPerUser = defaultdict(list)
usersPerAnime = defaultdict(set)
animePerUser = defaultdict(set)
ratingsDict = defaultdict(list)

def mylist():
    return [[] for j in range(81)]

#note there are 81 genres, and we will put individual scores into each one
genreScoresPerUser = defaultdict(mylist) 
for i in userData:
    ratingsDict[(i[0],i[1])] = i[4]
    scoresPerAnime[i[1]].append(i[4])
    scoresPerUser[i[0]].append(i[4])
    usersPerAnime[i[1]].add(i[0])
    animePerUser[i[0]].add(i[1])
    
    if i[1] in animelistdict:
        if 'genres' in animelistdict[i[1]]:
            for genre in animelistdict[i[1]]['genres']:
                genreScoresPerUser[i[0]][int(genre['id'])-1].append(i[4])
#data we are getting from entire dataset
dropsPerAnime = defaultdict(int)
dropsPerUser = defaultdict(int)
for i in readCSV('../data/user_animelist_details_16mil.txt'):
    if i[6] == 3:
        dropsPerAnime[i[1]] += 1
        dropsPerUser[i[0]] += 1

# %%
#this uses userData = completed_with_date, while the above does not

# %%
#getting one hot encoding of user and anime
userIDs, itemIDs = {},{}
for i in userData:
    u,a = i[0],i[1]
    if not u in userIDs: userIDs[u] = len(userIDs)
    if not a in itemIDs: itemIDs[a] = len(itemIDs)
nUsers,nItems = len(userIDs), len(itemIDs)
nUsers,nItems
# Out:
# (42176, 11249)

# %%
#let's start building our feature representation for the dataset
#We will have
#[one hot encoding of user, one hot encoding of item, user avgs of genre, item genres]
#length of feature will be 42176 + 11249 + 82 + 82

# %%
random.shuffle(userData)

# %%
# %time
X = scipy.sparse.lil_array((10000,nUsers+nItems+2*82))
Y = np.array([])
for i in range(len(userData[:10000])):
    Y = np.append(Y, userData[i][4])
    user = userIDs[userData[i][0]]
    anime = itemIDs[userData[i][1]]
    #one hot encodings
    X[i,user] = 1 
    X[i,nUsers+anime]=1
    #user averages of genres
    genreScores = genreScoresPerUser[userData[i][0]]
    for j in range(len(genreScores)):
        if len(genreScores[j]) != 0:
            X[i,nUsers + nItems + j] = sum(genreScores[j])/len(genreScores[j])
        #else:
            # X[i,nUsers + nItems + j] = 5 # we don't know how the user feels about anime in these genres
    #item scores
    if userData[i][1] in userData and 'genres' in animelistdict[userData[i][1]]:
        animeGenres = animelistdict[userData[i][1]]['genres']
        for j in range(len(animeGenres)):
            X[i, nUsers + nItems + 82 + j] = animeGenres[j]['id']
    #else:
        #these entries will be zero, so do nothing
    if i % 1000 == 0:
        print(i)
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 12.4 µs
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000

# %%
#dividing up dataset
Xtrain = X[:np.shape(X)[0]//2]
XValid = X[np.shape(X)[0]//2:np.shape(X)[0]*3//4]
XTest = X[np.shape(X)[0]*3//4:]
Ytrain = Y[:np.shape(Y)[0]//2]
YValid = Y[np.shape(Y)[0]//2:np.shape(X)[0]*3//4]
YTest = Y[np.shape(Y)[0]*3//4:]

# %%
#getting model
# param:
#  0. regression
#  1. model scale: 0.1
#  2. number of latent factor: 4
#  3. learning rate: 0.1
#  4. regular lambda: 0.01
#  5. use sgd optimization method
#  6. use 16 cpu threads
#  6. early stop at epoch 10
#  6. evaluation metric: rmse
fm_model = xl.FMModel(task='reg', init=0.1, k=200, lr=0.1, 
                      reg_lambda=0.01, opt='sgd', nthread= 16, epoch=10,
                      metric='rmse')

# %%
# Start to train
fm_model.fit(Xtrain, 
             Ytrain, eval_set=[XValid, YValid])
# Out:
# ----------------------------------------------------------------------------------------------
#            _
#           | |
#      __  _| |     ___  __ _ _ __ _ __
#      \ \/ / |    / _ \/ _` | '__| '_ \
#       >  <| |___|  __/ (_| | |  | | | |
#      /_/\_\_____/\___|\__,_|_|  |_| |_|
#
#         xLearn   -- 0.40 Version --
# ----------------------------------------------------------------------------------------------
#
# [------------] xLearn uses 16 threads for training task.
# [ ACTION     ] Read Problem ...
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (/tmp/tmpeo7groz1.bin) NOT found. Convert text file to binary file.
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (/tmp/tmpru2l9lkg.bin) NOT found. Convert text file to binary file.
# [------------] Number of Feature: 53506
# [------------] Time cost for reading problem: 0.09 (sec)
# [ ACTION     ] Initialize model ...
# [------------] Model size: 204.31 MB
# [------------] Time cost for model initial: 0.25 (sec)
# [ ACTION     ] Start to train ...
# [------------] Epoch      Train mse_loss       Test mse_loss           Test RMSD     Time cost (sec)
# [   10%      ]     1            1.531298            1.294299            1.608912                0.14
# [   20%      ]     2            1.484945            1.527137            1.747648                0.11
# [   30%      ]     3            1.508520            1.440064            1.697094                0.11
# [   40%      ]     4            1.495591            1.334152            1.633494                0.10
# [   50%      ]     5            1.563105            1.281034            1.600646                0.10
# [   60%      ]     6            1.504075            1.245595            1.578351                0.10
# [   70%      ]     7            1.550182            1.250424            1.581407                0.10
# [   80%      ]     8            1.529845            1.229412            1.568064                0.10
# [   90%      ]     9            1.449848            1.230815            1.568958                0.10
# [  100%      ]    10            1.508191            1.507298            1.736259                0.10
# [ ACTION     ] Early-stopping at epoch 8, best RMSD: 1.568064
# [ ACTION     ] Start to save model ...
# [------------] Model file: /tmp/tmppwlnhrir
# [------------] Time cost for saving model: 0.10 (sec)
# [ ACTION     ] Start to save txt model ...
# [------------] TXT Model file: /tmp/tmp1n253jad
# [------------] Time cost for saving txt model: 26.97 (sec)
# [ ACTION     ] Finish training
# [ ACTION     ] Clear the xLearn environment ...
# [------------] Total time cost: 28.61 (sec)

# %%
len(fm_model.weights[1])
# Out:
# 53506

# %%
YPred = fm_model.predict(XTest)
# Out:
# ----------------------------------------------------------------------------------------------
#            _
#           | |
#      __  _| |     ___  __ _ _ __ _ __
#      \ \/ / |    / _ \/ _` | '__| '_ \
#       >  <| |___|  __/ (_| | |  | | | |
#      /_/\_\_____/\___|\__,_|_|  |_| |_|
#
#         xLearn   -- 0.40 Version --
# ----------------------------------------------------------------------------------------------
#
# [------------] xLearn uses 12 threads for prediction task.
# [ ACTION     ] Load model ...
# [------------] Load model from /tmp/tmppwlnhrir
# [------------] Loss function: squared
# [------------] Score function: fm
# [------------] Number of Feature: 53506
# [------------] Number of K: 1000
# [------------] Time cost for loading model: 0.09 (sec)
# [ ACTION     ] Read Problem ...
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (/tmp/tmpe2gac4ox.bin) NOT found. Convert text file to binary file.
# [------------] Time cost for reading problem: 0.03 (sec)
# [ ACTION     ] Start to predict ...
# [------------] The test loss is: 29.120138
# [ ACTION     ] Clear the xLearn environment ...
# [------------] Total time cost: 0.15 (sec)

# %%
metrics.mean_squared_error(YTest, YPred, squared= False)
# Out:
# 1.5345710991809796

# %%
for i in range(len(YPred)):
    print('Predicted:', YPred[i], ' Actual:', YTest[i])
# Out:
# Predicted: 8.49395  Actual: 8.0
# Predicted: 7.637  Actual: 10.0
# Predicted: 7.14254  Actual: 9.0
# Predicted: 7.11809  Actual: 10.0
# Predicted: 7.61026  Actual: 5.0
# Predicted: 7.51548  Actual: 10.0
# Predicted: 8.03752  Actual: 10.0
# Predicted: 7.18239  Actual: 7.0
# Predicted: 7.94708  Actual: 8.0
# Predicted: 7.95407  Actual: 9.0
# Predicted: 7.57099  Actual: 9.0
# Predicted: 7.49275  Actual: 9.0
# Predicted: 7.53703  Actual: 7.0
# Predicted: 7.10314  Actual: 5.0
# Predicted: 7.59689  Actual: 9.0
# Predicted: 8.54355  Actual: 8.0
# Predicted: 8.58792  Actual: 10.0
# Predicted: 7.10882  Actual: 6.0
# Predicted: 7.90861  Actual: 6.0
# Predicted: 7.44243  Actual: 6.0
# Predicted: 7.83871  Actual: 3.0
# Predicted: 7.69549  Actual: 8.0
# Predicted: 7.58496  Actual: 8.0
# Predicted: 7.54078  Actual: 7.0
# Predicted: 7.50094  Actual: 8.0
# Predicted: 7.96195  Actual: 7.0
# Predicted: 8.37391  Actual: 9.0
# Predicted: 8.33446  Actual: 7.0
# Predicted: 7.86003  Actual: 8.0
# Predicted: 7.76168  Actual: 6.0
# Predicted: 8.29405  Actual: 10.0
# Predicted: 8.06926  Actual: 4.0
# Predicted: 8.21462  Actual: 10.0
# Predicted: 7.36596  Actual: 4.0
# Predicted: 8.06791  Actual: 8.0
# Predicted: 7.06701  Actual: 4.0
# Predicted: 7.69732  Actual: 9.0
# Predicted: 7.33504  Actual: 10.0
# Predicted: 7.68679  Actual: 10.0
# Predicted: 7.27253  Actual: 7.0
# Predicted: 8.1567  Actual: 8.0
# Predicted: 8.14902  Actual: 8.0
# Predicted: 8.03371  Actual: 8.0
# Predicted: 7.30109  Actual: 6.0
# Predicted: 8.27454  Actual: 9.0
# Predicted: 7.21674  Actual: 4.0
# Predicted: 7.96702  Actual: 7.0
# Predicted: 7.43235  Actual: 9.0
# Predicted: 7.6281  Actual: 9.0
# Predicted: 7.5231  Actual: 8.0
# Predicted: 7.68911  Actual: 8.0
# Predicted: 7.7918  Actual: 8.0
# Predicted: 7.65751  Actual: 7.0
# Predicted: 7.22632  Actual: 5.0
# Predicted: 7.67965  Actual: 9.0
# Predicted: 8.029  Actual: 8.0
# Predicted: 7.50247  Actual: 8.0
# Predicted: 7.62372  Actual: 8.0
# Predicted: 7.25589  Actual: 10.0
# Predicted: 7.52645  Actual: 9.0
# Predicted: 7.14245  Actual: 4.0
# Predicted: 7.29489  Actual: 6.0
# Predicted: 7.60964  Actual: 8.0
# Predicted: 7.07691  Actual: 7.0
# Predicted: 7.4988  Actual: 7.0
# Predicted: 7.9434  Actual: 7.0
# Predicted: 8.08253  Actual: 9.0
# Predicted: 8.00077  Actual: 7.0
# Predicted: 7.72874  Actual: 4.0
# Predicted: 7.16976  Actual: 8.0
# Predicted: 7.95523  Actual: 8.0
# Predicted: 7.56396  Actual: 7.0
# Predicted: 8.04018  Actual: 9.0
# Predicted: 7.75333  Actual: 8.0
# Predicted: 8.08389  Actual: 9.0
# Predicted: 7.22778  Actual: 8.0
# Predicted: 7.1611  Actual: 9.0
# Predicted: 7.2463  Actual: 7.0
# Predicted: 7.50273  Actual: 8.0
# Predicted: 7.01029  Actual: 9.0
# Predicted: 7.91608  Actual: 8.0
# Predicted: 7.30482  Actual: 10.0
# Predicted: 7.12519  Actual: 5.0
# Predicted: 7.43056  Actual: 7.0
# Predicted: 8.02818  Actual: 9.0
# Predicted: 7.8243  Actual: 10.0
# Predicted: 8.10356  Actual: 10.0
# Predicted: 7.18442  Actual: 8.0
# Predicted: 7.79925  Actual: 9.0
# Predicted: 7.39122  Actual: 5.0
# Predicted: 7.49238  Actual: 5.0
# Predicted: 7.33855  Actual: 9.0
# Predicted: 8.38707  Actual: 10.0
# Predicted: 8.01908  Actual: 7.0
# Predicted: 7.76182  Actual: 8.0
# Predicted: 7.63765  Actual: 7.0
# Predicted: 7.40292  Actual: 6.0
# Predicted: 8.26763  Actual: 8.0
# Predicted: 7.55024  Actual: 9.0
# Predicted: 7.3217  Actual: 4.0
# Predicted: 8.60347  Actual: 8.0
# Predicted: 7.05856  Actual: 7.0
# Predicted: 7.54593  Actual: 9.0
# Predicted: 7.16767  Actual: 6.0
# Predicted: 7.33358  Actual: 9.0
# Predicted: 7.58393  Actual: 10.0
# Predicted: 7.3675  Actual: 7.0
# Predicted: 7.99309  Actual: 10.0
# Predicted: 7.06796  Actual: 3.0
# Predicted: 7.08326  Actual: 8.0
# Predicted: 7.06692  Actual: 6.0
# Predicted: 7.45153  Actual: 7.0
# Predicted: 7.73388  Actual: 6.0
# Predicted: 7.09359  Actual: 7.0
# Predicted: 7.25567  Actual: 10.0
# Predicted: 7.25933  Actual: 6.0
# Predicted: 7.54209  Actual: 7.0
# Predicted: 7.92652  Actual: 8.0
# Predicted: 7.12495  Actual: 7.0
# Predicted: 8.18007  Actual: 8.0
# Predicted: 7.75389  Actual: 7.0
# Predicted: 7.53652  Actual: 7.0
# Predicted: 7.09647  Actual: 8.0
# Predicted: 7.71536  Actual: 5.0
# Predicted: 7.16118  Actual: 6.0
# Predicted: 8.24781  Actual: 10.0
# Predicted: 8.2782  Actual: 10.0
# Predicted: 7.11048  Actual: 4.0
# Predicted: 7.60933  Actual: 7.0
# Predicted: 7.88033  Actual: 8.0
# Predicted: 8.15137  Actual: 7.0
# Predicted: 8.25977  Actual: 9.0
# Predicted: 7.74356  Actual: 10.0
# Predicted: 7.98391  Actual: 7.0
# Predicted: 7.64504  Actual: 7.0
# Predicted: 7.3004  Actual: 8.0
# Predicted: 7.25019  Actual: 8.0
# Predicted: 7.67828  Actual: 8.0
# Predicted: 7.57832  Actual: 9.0
# Predicted: 7.12135  Actual: 7.0
# Predicted: 8.36466  Actual: 9.0
# Predicted: 7.67255  Actual: 7.0
# Predicted: 7.11233  Actual: 8.0
# Predicted: 7.43909  Actual: 8.0
# Predicted: 8.01589  Actual: 8.0
# Predicted: 7.91048  Actual: 6.0
# Predicted: 7.0319  Actual: 8.0
# Predicted: 7.65368  Actual: 8.0
# Predicted: 7.20434  Actual: 7.0
# Predicted: 7.81268  Actual: 9.0
# Predicted: 7.75622  Actual: 8.0
# Predicted: 7.59646  Actual: 5.0
# Predicted: 7.89401  Actual: 8.0
# Predicted: 8.31462  Actual: 7.0
# Predicted: 7.57149  Actual: 7.0
# Predicted: 7.18387  Actual: 9.0
# Predicted: 7.23936  Actual: 8.0
# Predicted: 7.60495  Actual: 9.0
# Predicted: 7.392  Actual: 6.0
# Predicted: 7.15539  Actual: 6.0
# Predicted: 7.61829  Actual: 9.0
# Predicted: 7.43935  Actual: 7.0
# Predicted: 7.8073  Actual: 7.0
# Predicted: 7.28615  Actual: 8.0
# Predicted: 7.15843  Actual: 10.0
# Predicted: 7.27213  Actual: 9.0
# Predicted: 7.81087  Actual: 8.0
# Predicted: 7.50523  Actual: 7.0
# Predicted: 8.62786  Actual: 10.0
# Predicted: 7.41362  Actual: 8.0
# Predicted: 7.30744  Actual: 7.0
# Predicted: 8.11136  Actual: 10.0
# Predicted: 7.77843  Actual: 8.0
# Predicted: 7.91282  Actual: 9.0
# Predicted: 8.02436  Actual: 7.0
# Predicted: 7.31555  Actual: 7.0
# Predicted: 7.08888  Actual: 7.0
# Predicted: 7.18381  Actual: 7.0
# Predicted: 7.43337  Actual: 8.0
# Predicted: 8.45443  Actual: 7.0
# Predicted: 7.09529  Actual: 8.0
# Predicted: 7.21897  Actual: 6.0
# Predicted: 7.10889  Actual: 4.0
# Predicted: 7.25714  Actual: 8.0
# Predicted: 7.42535  Actual: 5.0
# Predicted: 7.72482  Actual: 10.0
# Predicted: 7.0189  Actual: 9.0
# Predicted: 7.57599  Actual: 6.0
# Predicted: 7.10148  Actual: 6.0
# Predicted: 7.45217  Actual: 7.0
# Predicted: 7.77278  Actual: 10.0
# Predicted: 7.46222  Actual: 5.0
# Predicted: 7.43749  Actual: 10.0
# Predicted: 7.72986  Actual: 10.0
# Predicted: 8.04556  Actual: 7.0
# Predicted: 7.61472  Actual: 7.0
# Predicted: 7.57506  Actual: 7.0
# Predicted: 8.85555  Actual: 8.0
# Predicted: 7.42138  Actual: 8.0
# Predicted: 8.01361  Actual: 6.0
# Predicted: 7.51964  Actual: 8.0
# Predicted: 7.73288  Actual: 6.0
# Predicted: 7.66313  Actual: 7.0
# Predicted: 7.61268  Actual: 7.0
# Predicted: 7.51182  Actual: 8.0
# Predicted: 7.17899  Actual: 7.0
# Predicted: 7.43092  Actual: 9.0
# Predicted: 7.86222  Actual: 4.0
# Predicted: 8.32331  Actual: 5.0
# Predicted: 7.51135  Actual: 7.0
# Predicted: 7.37259  Actual: 6.0
# Predicted: 7.29367  Actual: 7.0
# Predicted: 7.34632  Actual: 7.0
# Predicted: 7.42702  Actual: 8.0
# Predicted: 7.27215  Actual: 9.0
# Predicted: 7.73902  Actual: 8.0
# Predicted: 7.57543  Actual: 8.0
# Predicted: 7.66504  Actual: 9.0
# Predicted: 7.37862  Actual: 4.0
# Predicted: 7.85804  Actual: 8.0
# Predicted: 7.59572  Actual: 9.0
# Predicted: 7.58035  Actual: 8.0
# Predicted: 7.93244  Actual: 9.0
# Predicted: 7.8744  Actual: 6.0
# Predicted: 7.34282  Actual: 8.0
# Predicted: 7.47718  Actual: 8.0
# Predicted: 7.75655  Actual: 6.0
# Predicted: 7.7429  Actual: 10.0
# Predicted: 8.06346  Actual: 7.0
# Predicted: 7.29861  Actual: 7.0
# Predicted: 7.89044  Actual: 10.0
# Predicted: 7.92718  Actual: 10.0
# Predicted: 7.53099  Actual: 5.0
# Predicted: 8.32282  Actual: 8.0
# Predicted: 7.47355  Actual: 7.0
# Predicted: 7.44663  Actual: 9.0
# Predicted: 8.70266  Actual: 10.0
# Predicted: 7.25614  Actual: 7.0
# Predicted: 7.95629  Actual: 6.0
# Predicted: 7.48561  Actual: 7.0
# Predicted: 7.43272  Actual: 8.0
# Predicted: 7.36303  Actual: 9.0
# Predicted: 8.16601  Actual: 9.0
# Predicted: 7.43241  Actual: 7.0
# Predicted: 8.0061  Actual: 10.0
# Predicted: 7.04858  Actual: 7.0
# Predicted: 7.1214  Actual: 8.0
# Predicted: 7.20633  Actual: 8.0
# Predicted: 7.23221  Actual: 8.0
# Predicted: 8.06507  Actual: 10.0
# Predicted: 7.65825  Actual: 10.0
# Predicted: 7.15466  Actual: 7.0
# Predicted: 7.58056  Actual: 8.0
# Predicted: 7.14302  Actual: 7.0
# Predicted: 7.64465  Actual: 6.0
# Predicted: 7.42752  Actual: 9.0
# Predicted: 8.03367  Actual: 9.0
# Predicted: 7.6696  Actual: 7.0
# Predicted: 7.2815  Actual: 7.0
# Predicted: 7.67022  Actual: 6.0
# Predicted: 7.73747  Actual: 9.0
# Predicted: 7.26609  Actual: 7.0
# Predicted: 7.12803  Actual: 8.0
# Predicted: 7.90675  Actual: 7.0
# Predicted: 8.23634  Actual: 9.0
# Predicted: 7.79497  Actual: 9.0
# Predicted: 7.45187  Actual: 9.0
# Predicted: 7.39134  Actual: 8.0
# Predicted: 7.68698  Actual: 9.0
# Predicted: 7.18652  Actual: 7.0
# Predicted: 7.14266  Actual: 6.0
# Predicted: 7.68113  Actual: 6.0
# Predicted: 7.14583  Actual: 8.0
# Predicted: 7.62984  Actual: 10.0
# Predicted: 7.3367  Actual: 8.0
# Predicted: 7.34406  Actual: 7.0
# Predicted: 7.90571  Actual: 10.0
# Predicted: 7.45546  Actual: 8.0
# Predicted: 7.58162  Actual: 9.0
# Predicted: 8.26651  Actual: 10.0
# Predicted: 7.30021  Actual: 8.0
# Predicted: 7.26373  Actual: 6.0
# Predicted: 7.27291  Actual: 7.0
# Predicted: 7.54337  Actual: 5.0
# Predicted: 7.70895  Actual: 6.0
# Predicted: 7.80779  Actual: 10.0
# Predicted: 7.30463  Actual: 7.0
# Predicted: 7.07103  Actual: 4.0
# Predicted: 8.29045  Actual: 7.0
# Predicted: 7.6059  Actual: 8.0
# Predicted: 8.0441  Actual: 9.0
# Predicted: 8.06302  Actual: 8.0
# Predicted: 7.52355  Actual: 7.0
# Predicted: 7.88327  Actual: 8.0
# Predicted: 7.76694  Actual: 9.0
# Predicted: 7.24848  Actual: 7.0
# Predicted: 7.26002  Actual: 9.0
# Predicted: 7.36804  Actual: 7.0
# Predicted: 7.58672  Actual: 7.0
# Predicted: 7.82891  Actual: 7.0
# Predicted: 7.83823  Actual: 9.0
# Predicted: 7.3183  Actual: 8.0
# Predicted: 8.2068  Actual: 9.0
# Predicted: 7.28497  Actual: 6.0
# Predicted: 7.73407  Actual: 7.0
# Predicted: 7.36028  Actual: 8.0
# Predicted: 7.50565  Actual: 9.0
# Predicted: 8.08006  Actual: 8.0
# Predicted: 7.72819  Actual: 6.0
# Predicted: 7.4242  Actual: 10.0
# Predicted: 7.74045  Actual: 10.0
# Predicted: 7.15173  Actual: 9.0
# Predicted: 8.23121  Actual: 9.0
# Predicted: 7.79217  Actual: 9.0
# Predicted: 8.58704  Actual: 10.0
# Predicted: 7.76579  Actual: 7.0
# Predicted: 7.9064  Actual: 9.0
# Predicted: 7.26781  Actual: 7.0
# Predicted: 9.03198  Actual: 7.0
# Predicted: 7.19106  Actual: 9.0
# Predicted: 7.42899  Actual: 9.0
# Predicted: 7.57  Actual: 8.0
# Predicted: 7.71981  Actual: 7.0
# Predicted: 7.51803  Actual: 6.0
# Predicted: 7.61979  Actual: 7.0
# Predicted: 7.59974  Actual: 8.0
# Predicted: 7.76446  Actual: 10.0
# Predicted: 7.85706  Actual: 8.0
# Predicted: 7.98016  Actual: 8.0
# Predicted: 7.32982  Actual: 5.0
# Predicted: 8.06994  Actual: 8.0
# Predicted: 7.56097  Actual: 7.0
# Predicted: 8.37839  Actual: 9.0
# Predicted: 8.09426  Actual: 7.0
# Predicted: 7.59773  Actual: 10.0
# Predicted: 7.75617  Actual: 8.0
# Predicted: 7.6467  Actual: 7.0
# Predicted: 7.56142  Actual: 5.0
# Predicted: 7.82699  Actual: 9.0
# Predicted: 7.77962  Actual: 6.0
# Predicted: 8.2801  Actual: 8.0
# Predicted: 7.59187  Actual: 5.0
# Predicted: 7.55663  Actual: 7.0
# Predicted: 7.37668  Actual: 9.0
# Predicted: 7.0527  Actual: 6.0
# Predicted: 7.43342  Actual: 8.0
# Predicted: 7.62405  Actual: 9.0
# Predicted: 7.25888  Actual: 7.0
# Predicted: 7.2913  Actual: 7.0
# Predicted: 7.72046  Actual: 8.0
# Predicted: 7.33597  Actual: 5.0
# Predicted: 7.42837  Actual: 7.0
# Predicted: 7.42737  Actual: 8.0
# Predicted: 7.80796  Actual: 10.0
# Predicted: 7.96486  Actual: 1.0
# Predicted: 7.58463  Actual: 9.0
# Predicted: 7.61693  Actual: 8.0
# Predicted: 7.37583  Actual: 5.0
# Predicted: 7.26031  Actual: 7.0
# Predicted: 7.64631  Actual: 8.0
# Predicted: 8.33009  Actual: 9.0
# Predicted: 7.91542  Actual: 9.0
# Predicted: 7.9043  Actual: 8.0
# Predicted: 7.69758  Actual: 10.0
# Predicted: 7.48634  Actual: 8.0
# Predicted: 7.45968  Actual: 8.0
# Predicted: 7.78008  Actual: 6.0
# Predicted: 7.0823  Actual: 7.0
# Predicted: 7.91824  Actual: 10.0
# Predicted: 7.40555  Actual: 6.0
# Predicted: 7.82387  Actual: 5.0
# Predicted: 7.18244  Actual: 10.0
# Predicted: 7.83682  Actual: 7.0
# Predicted: 7.92786  Actual: 7.0
# Predicted: 7.70757  Actual: 6.0
# Predicted: 8.51672  Actual: 8.0
# Predicted: 7.30128  Actual: 8.0
# Predicted: 7.43219  Actual: 8.0
# Predicted: 7.6096  Actual: 10.0
# Predicted: 7.31602  Actual: 5.0
# Predicted: 8.65126  Actual: 9.0
# Predicted: 7.58193  Actual: 10.0
# Predicted: 7.25455  Actual: 7.0
# Predicted: 7.60039  Actual: 8.0
# Predicted: 8.24244  Actual: 10.0
# Predicted: 8.40065  Actual: 8.0
# Predicted: 7.6238  Actual: 7.0
# Predicted: 7.66412  Actual: 8.0
# Predicted: 7.96402  Actual: 10.0
# Predicted: 7.66494  Actual: 9.0
# Predicted: 8.20125  Actual: 7.0
# Predicted: 7.14132  Actual: 7.0
# Predicted: 7.32036  Actual: 7.0
# Predicted: 7.57271  Actual: 8.0
# Predicted: 7.44702  Actual: 8.0
# Predicted: 7.23933  Actual: 7.0
# Predicted: 7.14404  Actual: 6.0
# Predicted: 7.60074  Actual: 6.0
# Predicted: 7.20638  Actual: 7.0
# Predicted: 7.58753  Actual: 7.0
# Predicted: 7.45558  Actual: 6.0
# Predicted: 7.92655  Actual: 7.0
# Predicted: 7.7228  Actual: 8.0
# Predicted: 7.50802  Actual: 8.0
# Predicted: 7.30507  Actual: 7.0
# Predicted: 6.81285  Actual: 4.0
# Predicted: 8.18941  Actual: 9.0
# Predicted: 7.69724  Actual: 7.0
# Predicted: 7.06015  Actual: 8.0
# Predicted: 7.95636  Actual: 8.0
# Predicted: 7.13805  Actual: 7.0
# Predicted: 8.01195  Actual: 9.0
# Predicted: 7.45917  Actual: 10.0
# Predicted: 8.12772  Actual: 10.0
# Predicted: 7.75789  Actual: 9.0
# Predicted: 8.61064  Actual: 10.0
# Predicted: 8.01157  Actual: 8.0
# Predicted: 7.1813  Actual: 6.0
# Predicted: 7.10466  Actual: 6.0
# Predicted: 7.69327  Actual: 8.0
# Predicted: 7.72042  Actual: 8.0
# Predicted: 7.00065  Actual: 6.0
# Predicted: 7.45509  Actual: 8.0
# Predicted: 7.81553  Actual: 8.0
# Predicted: 7.63472  Actual: 9.0
# Predicted: 7.99169  Actual: 7.0
# Predicted: 8.23587  Actual: 10.0
# Predicted: 7.82506  Actual: 9.0
# Predicted: 7.50108  Actual: 8.0
# Predicted: 7.10445  Actual: 7.0
# Predicted: 7.2976  Actual: 8.0
# Predicted: 7.54227  Actual: 8.0
# Predicted: 7.25634  Actual: 7.0
# Predicted: 7.84491  Actual: 8.0
# Predicted: 7.66515  Actual: 6.0
# Predicted: 7.27273  Actual: 10.0
# Predicted: 7.7898  Actual: 9.0
# Predicted: 7.11727  Actual: 9.0
# Predicted: 8.26486  Actual: 10.0
# Predicted: 7.56189  Actual: 7.0
# Predicted: 7.99706  Actual: 10.0
# Predicted: 7.30929  Actual: 9.0
# Predicted: 7.4981  Actual: 8.0
# Predicted: 8.21662  Actual: 8.0
# Predicted: 7.48925  Actual: 9.0
# Predicted: 7.63746  Actual: 10.0
# Predicted: 8.52324  Actual: 5.0
# Predicted: 7.50821  Actual: 8.0
# Predicted: 7.35102  Actual: 6.0
# Predicted: 7.47138  Actual: 4.0
# Predicted: 7.75734  Actual: 10.0
# Predicted: 8.03501  Actual: 7.0
# Predicted: 7.18144  Actual: 5.0
# Predicted: 8.62824  Actual: 6.0
# Predicted: 7.58619  Actual: 8.0
# Predicted: 7.81075  Actual: 8.0
# Predicted: 7.31596  Actual: 8.0
# Predicted: 8.01702  Actual: 9.0
# Predicted: 7.57649  Actual: 3.0
# Predicted: 7.68177  Actual: 7.0
# Predicted: 7.62634  Actual: 8.0
# Predicted: 8.0628  Actual: 9.0
# Predicted: 7.91207  Actual: 5.0
# Predicted: 7.46943  Actual: 10.0
# Predicted: 7.05795  Actual: 8.0
# Predicted: 8.22225  Actual: 8.0
# Predicted: 8.08998  Actual: 7.0
# Predicted: 7.5937  Actual: 7.0
# Predicted: 8.06901  Actual: 8.0
# Predicted: 7.61556  Actual: 9.0
# Predicted: 7.18146  Actual: 9.0
# Predicted: 7.04761  Actual: 4.0
# Predicted: 7.53961  Actual: 6.0
# Predicted: 7.97416  Actual: 9.0
# Predicted: 7.10629  Actual: 7.0
# Predicted: 7.46922  Actual: 9.0
# Predicted: 7.63797  Actual: 5.0
# Predicted: 7.74736  Actual: 8.0
# Predicted: 7.64571  Actual: 7.0
# Predicted: 7.45251  Actual: 9.0
# Predicted: 7.45754  Actual: 9.0
# Predicted: 7.59545  Actual: 8.0
# Predicted: 8.09834  Actual: 10.0
# Predicted: 7.69786  Actual: 8.0
# Predicted: 7.97061  Actual: 8.0
# Predicted: 7.72319  Actual: 9.0
# Predicted: 7.54276  Actual: 9.0
# Predicted: 7.67672  Actual: 10.0
# Predicted: 7.92433  Actual: 7.0
# Predicted: 7.58789  Actual: 8.0
# Predicted: 7.6696  Actual: 7.0
# Predicted: 7.04802  Actual: 7.0
# Predicted: 7.88956  Actual: 5.0
# Predicted: 7.60628  Actual: 8.0
# Predicted: 7.20282  Actual: 8.0
# Predicted: 7.86473  Actual: 4.0
# Predicted: 7.35625  Actual: 8.0
# Predicted: 7.53386  Actual: 7.0
# Predicted: 7.8648  Actual: 7.0
# Predicted: 7.79604  Actual: 7.0
# Predicted: 7.66398  Actual: 7.0
# Predicted: 8.14105  Actual: 10.0
# Predicted: 7.49203  Actual: 8.0
# Predicted: 7.836  Actual: 7.0
# Predicted: 7.68091  Actual: 10.0
# Predicted: 7.62171  Actual: 8.0
# Predicted: 7.93097  Actual: 9.0
# Predicted: 7.28147  Actual: 5.0
# Predicted: 8.12743  Actual: 5.0
# Predicted: 8.10692  Actual: 9.0
# Predicted: 7.389  Actual: 8.0
# Predicted: 8.33398  Actual: 9.0
# Predicted: 7.8032  Actual: 4.0
# Predicted: 7.5235  Actual: 7.0
# Predicted: 7.68618  Actual: 8.0
# Predicted: 7.83639  Actual: 8.0
# Predicted: 8.20931  Actual: 9.0
# Predicted: 7.32124  Actual: 7.0
# Predicted: 7.6524  Actual: 10.0
# Predicted: 7.81239  Actual: 9.0
# Predicted: 7.59745  Actual: 9.0
# Predicted: 7.70778  Actual: 9.0
# Predicted: 7.87183  Actual: 5.0
# Predicted: 7.76631  Actual: 5.0
# Predicted: 7.85478  Actual: 8.0
# Predicted: 7.82711  Actual: 6.0
# Predicted: 7.89475  Actual: 7.0
# Predicted: 7.52248  Actual: 8.0
# Predicted: 8.10326  Actual: 7.0
# Predicted: 7.47045  Actual: 10.0
# Predicted: 7.76794  Actual: 10.0
# Predicted: 7.97936  Actual: 9.0
# Predicted: 7.38443  Actual: 6.0
# Predicted: 7.34514  Actual: 10.0
# Predicted: 7.50063  Actual: 7.0
# Predicted: 7.51075  Actual: 8.0
# Predicted: 7.37949  Actual: 8.0
# Predicted: 7.96639  Actual: 6.0
# Predicted: 8.67081  Actual: 9.0
# Predicted: 8.0516  Actual: 7.0
# Predicted: 7.72296  Actual: 9.0
# Predicted: 7.28052  Actual: 5.0
# Predicted: 8.52637  Actual: 9.0
# Predicted: 7.5795  Actual: 7.0
# Predicted: 8.10772  Actual: 10.0
# Predicted: 7.31975  Actual: 9.0
# Predicted: 7.76584  Actual: 7.0
# Predicted: 7.40279  Actual: 1.0
# Predicted: 7.47849  Actual: 8.0
# Predicted: 7.56384  Actual: 6.0
# Predicted: 7.43363  Actual: 7.0
# Predicted: 7.45601  Actual: 10.0
# Predicted: 7.95053  Actual: 8.0
# Predicted: 7.59427  Actual: 9.0
# Predicted: 7.48206  Actual: 8.0
# Predicted: 7.57896  Actual: 2.0
# Predicted: 7.77509  Actual: 7.0
# Predicted: 7.62885  Actual: 8.0
# Predicted: 7.80098  Actual: 8.0
# Predicted: 8.02842  Actual: 5.0
# Predicted: 8.12889  Actual: 10.0
# Predicted: 8.67156  Actual: 10.0
# Predicted: 7.25445  Actual: 6.0
# Predicted: 7.22316  Actual: 8.0
# Predicted: 7.42584  Actual: 9.0
# Predicted: 7.31374  Actual: 9.0
# Predicted: 7.6919  Actual: 6.0
# Predicted: 7.29386  Actual: 10.0
# Predicted: 7.70225  Actual: 8.0
# Predicted: 7.55762  Actual: 9.0
# Predicted: 7.7245  Actual: 8.0
# Predicted: 7.25056  Actual: 6.0
# Predicted: 7.78233  Actual: 8.0
# Predicted: 7.29745  Actual: 9.0
# Predicted: 7.03536  Actual: 1.0
# Predicted: 7.74554  Actual: 6.0
# Predicted: 7.13411  Actual: 9.0
# Predicted: 7.51478  Actual: 10.0
# Predicted: 7.44494  Actual: 7.0
# Predicted: 7.7635  Actual: 9.0
# Predicted: 7.5364  Actual: 7.0
# Predicted: 8.3321  Actual: 8.0
# Predicted: 7.27503  Actual: 5.0
# Predicted: 7.35549  Actual: 8.0
# Predicted: 7.52281  Actual: 9.0
# Predicted: 8.00153  Actual: 7.0
# Predicted: 8.04469  Actual: 8.0
# Predicted: 7.75504  Actual: 10.0
# Predicted: 8.06216  Actual: 8.0
# Predicted: 7.46207  Actual: 9.0
# Predicted: 7.65277  Actual: 7.0
# Predicted: 7.60944  Actual: 7.0
# Predicted: 7.21151  Actual: 8.0
# Predicted: 7.32773  Actual: 8.0
# Predicted: 7.3637  Actual: 9.0
# Predicted: 8.36983  Actual: 10.0
# Predicted: 7.89942  Actual: 7.0
# Predicted: 7.62369  Actual: 8.0
# Predicted: 7.50627  Actual: 8.0
# Predicted: 7.71951  Actual: 9.0
# Predicted: 8.09477  Actual: 8.0
# Predicted: 7.44628  Actual: 8.0
# Predicted: 8.4628  Actual: 9.0
# Predicted: 7.38874  Actual: 5.0
# Predicted: 7.27677  Actual: 5.0
# Predicted: 7.00886  Actual: 10.0
# Predicted: 8.14807  Actual: 6.0
# Predicted: 7.47668  Actual: 9.0
# Predicted: 8.21368  Actual: 7.0
# Predicted: 8.62592  Actual: 9.0
# Predicted: 7.70433  Actual: 5.0
# Predicted: 7.51372  Actual: 4.0
# Predicted: 7.92859  Actual: 7.0
# Predicted: 7.7188  Actual: 9.0
# Predicted: 7.39162  Actual: 8.0
# Predicted: 7.60352  Actual: 7.0
# Predicted: 8.20853  Actual: 6.0
# Predicted: 7.64285  Actual: 8.0
# Predicted: 7.9794  Actual: 10.0
# Predicted: 7.81431  Actual: 9.0
# Predicted: 7.71756  Actual: 8.0
# Predicted: 7.38335  Actual: 8.0
# Predicted: 7.8135  Actual: 8.0
# Predicted: 7.75597  Actual: 6.0
# Predicted: 7.35521  Actual: 9.0
# Predicted: 7.03696  Actual: 5.0
# Predicted: 7.35514  Actual: 9.0
# Predicted: 7.23635  Actual: 8.0
# Predicted: 7.62014  Actual: 5.0
# Predicted: 8.10145  Actual: 10.0
# Predicted: 7.97291  Actual: 8.0
# Predicted: 7.65875  Actual: 8.0
# Predicted: 8.00869  Actual: 9.0
# Predicted: 8.60166  Actual: 9.0
# Predicted: 7.3881  Actual: 7.0
# Predicted: 7.40576  Actual: 9.0
# Predicted: 7.85876  Actual: 7.0
# Predicted: 7.52331  Actual: 6.0
# Predicted: 7.7467  Actual: 7.0
# Predicted: 7.24278  Actual: 7.0
# Predicted: 7.10802  Actual: 8.0
# Predicted: 7.2154  Actual: 6.0
# Predicted: 7.64284  Actual: 7.0
# Predicted: 7.82007  Actual: 10.0
# Predicted: 7.21571  Actual: 8.0
# Predicted: 7.81715  Actual: 10.0
# Predicted: 7.40471  Actual: 7.0
# Predicted: 7.20615  Actual: 8.0
# Predicted: 7.73288  Actual: 8.0
# Predicted: 7.81483  Actual: 10.0
# Predicted: 7.10066  Actual: 6.0
# Predicted: 8.11148  Actual: 7.0
# Predicted: 7.19786  Actual: 9.0
# Predicted: 7.18895  Actual: 7.0
# Predicted: 8.16149  Actual: 9.0
# Predicted: 7.245  Actual: 6.0
# Predicted: 7.22273  Actual: 10.0
# Predicted: 7.41379  Actual: 10.0
# Predicted: 7.13409  Actual: 5.0
# Predicted: 7.61106  Actual: 9.0
# Predicted: 7.45348  Actual: 9.0
# Predicted: 8.02873  Actual: 8.0
# Predicted: 7.57393  Actual: 10.0
# Predicted: 7.61733  Actual: 6.0
# Predicted: 7.7524  Actual: 8.0
# Predicted: 7.67832  Actual: 6.0
# Predicted: 7.0319  Actual: 4.0
# Predicted: 7.0698  Actual: 6.0
# Predicted: 7.38178  Actual: 7.0
# Predicted: 7.14915  Actual: 4.0
# Predicted: 7.05329  Actual: 4.0
# Predicted: 7.778  Actual: 9.0
# Predicted: 7.86865  Actual: 8.0
# Predicted: 7.13675  Actual: 4.0
# Predicted: 7.40485  Actual: 8.0
# Predicted: 8.5759  Actual: 10.0
# Predicted: 7.30977  Actual: 9.0
# Predicted: 7.5949  Actual: 7.0
# Predicted: 7.05512  Actual: 7.0
# Predicted: 7.14036  Actual: 6.0
# Predicted: 7.53554  Actual: 9.0
# Predicted: 8.03892  Actual: 10.0
# Predicted: 7.37323  Actual: 8.0
# Predicted: 7.78756  Actual: 9.0
# Predicted: 7.40229  Actual: 7.0
# Predicted: 7.33998  Actual: 6.0
# Predicted: 7.68094  Actual: 10.0
# Predicted: 7.50575  Actual: 8.0
# Predicted: 8.13373  Actual: 7.0
# Predicted: 7.84597  Actual: 5.0
# Predicted: 8.2423  Actual: 9.0
# Predicted: 8.26116  Actual: 9.0
# Predicted: 7.33824  Actual: 6.0
# Predicted: 7.07639  Actual: 7.0
# Predicted: 7.76146  Actual: 8.0
# Predicted: 7.68869  Actual: 7.0
# Predicted: 7.58664  Actual: 8.0
# Predicted: 7.45416  Actual: 7.0
# Predicted: 7.65504  Actual: 6.0
# Predicted: 7.78094  Actual: 7.0
# Predicted: 7.23838  Actual: 8.0
# Predicted: 7.38352  Actual: 7.0
# Predicted: 8.38396  Actual: 9.0
# Predicted: 7.948  Actual: 9.0
# Predicted: 7.78429  Actual: 7.0
# Predicted: 7.76486  Actual: 8.0
# Predicted: 7.81347  Actual: 6.0
# Predicted: 8.66576  Actual: 9.0
# Predicted: 7.70099  Actual: 7.0
# Predicted: 8.01958  Actual: 8.0
# Predicted: 8.18603  Actual: 9.0
# Predicted: 7.7467  Actual: 9.0
# Predicted: 7.12457  Actual: 7.0
# Predicted: 7.19713  Actual: 5.0
# Predicted: 7.37339  Actual: 8.0
# Predicted: 7.51685  Actual: 8.0
# Predicted: 7.3759  Actual: 8.0
# Predicted: 7.78903  Actual: 8.0
# Predicted: 7.05791  Actual: 8.0
# Predicted: 7.8236  Actual: 9.0
# Predicted: 7.70973  Actual: 10.0
# Predicted: 7.37195  Actual: 7.0
# Predicted: 7.50189  Actual: 8.0
# Predicted: 8.1489  Actual: 9.0
# Predicted: 7.87486  Actual: 7.0
# Predicted: 7.54165  Actual: 8.0
# Predicted: 7.51746  Actual: 7.0
# Predicted: 8.16119  Actual: 10.0
# Predicted: 7.44867  Actual: 8.0
# Predicted: 7.27129  Actual: 8.0
# Predicted: 7.84179  Actual: 9.0
# Predicted: 7.57277  Actual: 8.0
# Predicted: 7.3802  Actual: 9.0
# Predicted: 7.22539  Actual: 7.0
# Predicted: 7.45769  Actual: 7.0
# Predicted: 7.0363  Actual: 7.0
# Predicted: 7.41789  Actual: 8.0
# Predicted: 7.61348  Actual: 8.0
# Predicted: 7.80182  Actual: 9.0
# Predicted: 7.42981  Actual: 6.0
# Predicted: 7.79487  Actual: 8.0
# Predicted: 7.41143  Actual: 9.0
# Predicted: 7.58767  Actual: 9.0
# Predicted: 7.1143  Actual: 8.0
# Predicted: 7.26863  Actual: 10.0
# Predicted: 7.57239  Actual: 5.0
# Predicted: 7.28056  Actual: 9.0
# Predicted: 7.77644  Actual: 5.0
# Predicted: 7.22129  Actual: 10.0
# Predicted: 7.59202  Actual: 6.0
# Predicted: 7.64922  Actual: 6.0
# Predicted: 8.37012  Actual: 9.0
# Predicted: 7.11303  Actual: 7.0
# Predicted: 7.6572  Actual: 9.0
# Predicted: 7.61428  Actual: 7.0
# Predicted: 7.39034  Actual: 9.0
# Predicted: 7.25455  Actual: 8.0
# Predicted: 7.41835  Actual: 10.0
# Predicted: 7.19359  Actual: 5.0
# Predicted: 7.30021  Actual: 7.0
# Predicted: 7.44202  Actual: 7.0
# Predicted: 7.38183  Actual: 8.0
# Predicted: 7.10332  Actual: 8.0
# Predicted: 7.19826  Actual: 7.0
# Predicted: 7.69091  Actual: 8.0
# Predicted: 8.46587  Actual: 8.0
# Predicted: 7.95227  Actual: 9.0
# Predicted: 8.36608  Actual: 8.0
# Predicted: 7.43755  Actual: 9.0
# Predicted: 7.57335  Actual: 10.0
# Predicted: 7.96812  Actual: 9.0
# Predicted: 8.12846  Actual: 5.0
# Predicted: 7.06179  Actual: 7.0
# Predicted: 8.53424  Actual: 9.0
# Predicted: 7.71734  Actual: 10.0
# Predicted: 7.54622  Actual: 7.0
# Predicted: 8.03634  Actual: 6.0
# Predicted: 7.7622  Actual: 10.0
# Predicted: 7.7625  Actual: 8.0
# Predicted: 7.21303  Actual: 6.0
# Predicted: 7.85504  Actual: 8.0
# Predicted: 7.5503  Actual: 8.0
# Predicted: 7.45679  Actual: 8.0
# Predicted: 7.30539  Actual: 9.0
# Predicted: 7.87101  Actual: 5.0
# Predicted: 7.67436  Actual: 8.0
# Predicted: 7.04873  Actual: 8.0
# Predicted: 7.45632  Actual: 7.0
# Predicted: 7.75509  Actual: 7.0
# Predicted: 7.9038  Actual: 10.0
# Predicted: 7.83777  Actual: 9.0
# Predicted: 7.84653  Actual: 7.0
# Predicted: 7.48665  Actual: 7.0
# Predicted: 7.14642  Actual: 6.0
# Predicted: 7.62379  Actual: 7.0
# Predicted: 7.2509  Actual: 6.0
# Predicted: 7.75965  Actual: 8.0
# Predicted: 7.1557  Actual: 9.0
# Predicted: 7.23073  Actual: 8.0
# Predicted: 7.61278  Actual: 8.0
# Predicted: 7.54938  Actual: 7.0
# Predicted: 7.58088  Actual: 6.0
# Predicted: 8.06186  Actual: 9.0
# Predicted: 7.24768  Actual: 7.0
# Predicted: 7.07399  Actual: 5.0
# Predicted: 7.08902  Actual: 7.0
# Predicted: 7.19137  Actual: 8.0
# Predicted: 7.76906  Actual: 7.0
# Predicted: 7.6162  Actual: 7.0
# Predicted: 7.80244  Actual: 7.0
# Predicted: 8.10783  Actual: 9.0
# Predicted: 8.21613  Actual: 10.0
# Predicted: 7.41544  Actual: 7.0
# Predicted: 7.66981  Actual: 8.0
# Predicted: 7.23204  Actual: 9.0
# Predicted: 7.15649  Actual: 8.0
# Predicted: 7.83596  Actual: 9.0
# Predicted: 7.80134  Actual: 9.0
# Predicted: 7.50956  Actual: 10.0
# Predicted: 7.1712  Actual: 7.0
# Predicted: 7.6611  Actual: 8.0
# Predicted: 8.06204  Actual: 9.0
# Predicted: 7.50547  Actual: 7.0
# Predicted: 7.70753  Actual: 10.0
# Predicted: 7.47592  Actual: 10.0
# Predicted: 7.52595  Actual: 5.0
# Predicted: 7.19819  Actual: 6.0
# Predicted: 7.65911  Actual: 3.0
# Predicted: 7.12588  Actual: 7.0
# Predicted: 7.63413  Actual: 7.0
# Predicted: 7.86995  Actual: 6.0
# Predicted: 7.26849  Actual: 6.0
# Predicted: 7.78807  Actual: 6.0
# Predicted: 7.11454  Actual: 10.0
# Predicted: 7.91087  Actual: 10.0
# Predicted: 7.43279  Actual: 7.0
# Predicted: 7.5009  Actual: 6.0
# Predicted: 7.63471  Actual: 5.0
# Predicted: 8.27071  Actual: 8.0
# Predicted: 8.05706  Actual: 8.0
# Predicted: 7.72644  Actual: 6.0
# Predicted: 7.47322  Actual: 9.0
# Predicted: 8.05543  Actual: 7.0
# Predicted: 7.35004  Actual: 10.0
# Predicted: 7.35146  Actual: 8.0
# Predicted: 8.04855  Actual: 8.0
# Predicted: 7.29471  Actual: 9.0
# Predicted: 7.23876  Actual: 3.0
# Predicted: 7.8953  Actual: 3.0
# Predicted: 7.602  Actual: 6.0
# Predicted: 7.11833  Actual: 8.0
# Predicted: 7.05881  Actual: 5.0
# Predicted: 7.7113  Actual: 8.0
# Predicted: 7.24705  Actual: 8.0
# Predicted: 7.60656  Actual: 10.0
# Predicted: 7.57054  Actual: 7.0
# Predicted: 7.69215  Actual: 8.0
# Predicted: 8.22386  Actual: 9.0
# Predicted: 7.48282  Actual: 10.0
# Predicted: 8.01963  Actual: 10.0
# Predicted: 7.66347  Actual: 7.0
# Predicted: 7.54091  Actual: 8.0
# Predicted: 7.71965  Actual: 7.0
# Predicted: 8.25109  Actual: 10.0
# Predicted: 7.53496  Actual: 8.0
# Predicted: 7.80172  Actual: 7.0
# Predicted: 7.80502  Actual: 10.0
# Predicted: 7.2638  Actual: 7.0
# Predicted: 7.15524  Actual: 7.0
# Predicted: 7.1114  Actual: 7.0
# Predicted: 7.57709  Actual: 10.0
# Predicted: 7.13998  Actual: 6.0
# Predicted: 8.21926  Actual: 10.0
# Predicted: 7.37574  Actual: 6.0
# Predicted: 7.29134  Actual: 10.0
# Predicted: 7.63842  Actual: 5.0
# Predicted: 7.5879  Actual: 7.0
# Predicted: 7.0724  Actual: 8.0
# Predicted: 8.51134  Actual: 8.0
# Predicted: 8.0071  Actual: 8.0
# Predicted: 7.79735  Actual: 7.0
# Predicted: 7.58301  Actual: 3.0
# Predicted: 7.15632  Actual: 8.0
# Predicted: 7.66092  Actual: 8.0
# Predicted: 7.71775  Actual: 10.0
# Predicted: 7.70014  Actual: 10.0
# Predicted: 7.49718  Actual: 6.0
# Predicted: 7.40172  Actual: 6.0
# Predicted: 8.28911  Actual: 8.0
# Predicted: 7.18376  Actual: 7.0
# Predicted: 7.17648  Actual: 6.0
# Predicted: 7.44569  Actual: 6.0
# Predicted: 7.2698  Actual: 8.0
# Predicted: 7.38236  Actual: 7.0
# Predicted: 7.74597  Actual: 7.0
# Predicted: 7.93503  Actual: 8.0
# Predicted: 7.3603  Actual: 8.0
# Predicted: 7.74129  Actual: 10.0
# Predicted: 7.75286  Actual: 9.0
# Predicted: 7.43578  Actual: 7.0
# Predicted: 7.25572  Actual: 8.0
# Predicted: 7.89526  Actual: 8.0
# Predicted: 7.59138  Actual: 8.0
# Predicted: 7.79163  Actual: 8.0
# Predicted: 7.44649  Actual: 10.0
# Predicted: 8.02363  Actual: 10.0
# Predicted: 7.319  Actual: 10.0
# Predicted: 7.89294  Actual: 9.0
# Predicted: 7.90791  Actual: 5.0
# Predicted: 7.93482  Actual: 6.0
# Predicted: 7.6323  Actual: 8.0
# Predicted: 7.2824  Actual: 9.0
# Predicted: 7.14037  Actual: 9.0
# Predicted: 7.12519  Actual: 7.0
# Predicted: 7.1321  Actual: 7.0
# Predicted: 7.4534  Actual: 8.0
# Predicted: 7.56233  Actual: 8.0
# Predicted: 7.46976  Actual: 8.0
# Predicted: 7.71268  Actual: 7.0
# Predicted: 7.916  Actual: 6.0
# Predicted: 7.23323  Actual: 7.0
# Predicted: 7.50288  Actual: 9.0
# Predicted: 7.20538  Actual: 8.0
# Predicted: 8.03998  Actual: 8.0
# Predicted: 8.37643  Actual: 9.0
# Predicted: 8.43431  Actual: 7.0
# Predicted: 8.07162  Actual: 7.0
# Predicted: 8.01305  Actual: 8.0
# Predicted: 7.59548  Actual: 10.0
# Predicted: 8.14536  Actual: 9.0
# Predicted: 7.909  Actual: 7.0
# Predicted: 7.45281  Actual: 10.0
# Predicted: 7.30643  Actual: 8.0
# Predicted: 7.96821  Actual: 9.0
# Predicted: 7.96136  Actual: 8.0
# Predicted: 7.73945  Actual: 7.0
# Predicted: 7.67175  Actual: 9.0
# Predicted: 7.27051  Actual: 6.0
# Predicted: 7.05458  Actual: 7.0
# Predicted: 7.41933  Actual: 8.0
# Predicted: 7.62865  Actual: 7.0
# Predicted: 7.37833  Actual: 9.0
# Predicted: 7.68859  Actual: 8.0
# Predicted: 8.10106  Actual: 8.0
# Predicted: 7.97109  Actual: 9.0
# Predicted: 7.54164  Actual: 7.0
# Predicted: 7.29373  Actual: 9.0
# Predicted: 7.90296  Actual: 6.0
# Predicted: 8.43536  Actual: 9.0
# Predicted: 7.63021  Actual: 7.0
# Predicted: 7.85032  Actual: 8.0
# Predicted: 7.84596  Actual: 7.0
# Predicted: 7.86028  Actual: 10.0
# Predicted: 7.41104  Actual: 6.0
# Predicted: 7.49265  Actual: 8.0
# Predicted: 7.11143  Actual: 7.0
# Predicted: 7.27756  Actual: 7.0
# Predicted: 8.29775  Actual: 9.0
# Predicted: 7.40714  Actual: 10.0
# Predicted: 7.25689  Actual: 6.0
# Predicted: 7.78523  Actual: 10.0
# Predicted: 7.14516  Actual: 8.0
# Predicted: 7.61308  Actual: 9.0
# Predicted: 7.48423  Actual: 8.0
# Predicted: 7.32531  Actual: 6.0
# Predicted: 7.51069  Actual: 6.0
# Predicted: 8.07007  Actual: 10.0
# Predicted: 7.6998  Actual: 7.0
# Predicted: 7.72525  Actual: 7.0
# Predicted: 7.40133  Actual: 8.0
# Predicted: 7.60974  Actual: 9.0
# Predicted: 7.76498  Actual: 8.0
# Predicted: 7.77386  Actual: 8.0
# Predicted: 7.57427  Actual: 5.0
# Predicted: 7.72595  Actual: 8.0
# Predicted: 7.73014  Actual: 7.0
# Predicted: 7.62812  Actual: 10.0
# Predicted: 8.08041  Actual: 7.0
# Predicted: 8.12994  Actual: 8.0
# Predicted: 7.78635  Actual: 7.0
# Predicted: 7.23123  Actual: 8.0
# Predicted: 7.25481  Actual: 10.0
# Predicted: 7.28038  Actual: 6.0
# Predicted: 6.81253  Actual: 5.0
# Predicted: 7.41698  Actual: 8.0
# Predicted: 7.3294  Actual: 7.0
# Predicted: 7.94298  Actual: 8.0
# Predicted: 7.5977  Actual: 7.0
# Predicted: 7.44501  Actual: 7.0
# Predicted: 7.48535  Actual: 5.0
# Predicted: 7.52019  Actual: 7.0
# Predicted: 7.88301  Actual: 10.0
# Predicted: 7.20442  Actual: 10.0
# Predicted: 7.3818  Actual: 10.0
# Predicted: 7.79373  Actual: 5.0
# Predicted: 7.50501  Actual: 7.0
# Predicted: 7.51021  Actual: 10.0
# Predicted: 8.18411  Actual: 9.0
# Predicted: 7.57089  Actual: 10.0
# Predicted: 7.56403  Actual: 1.0
# Predicted: 8.20599  Actual: 10.0
# Predicted: 7.54892  Actual: 7.0
# Predicted: 7.97139  Actual: 7.0
# Predicted: 7.39941  Actual: 9.0
# Predicted: 7.39045  Actual: 7.0
# Predicted: 7.88049  Actual: 7.0
# Predicted: 7.46923  Actual: 10.0
# Predicted: 7.50215  Actual: 7.0
# Predicted: 7.5657  Actual: 9.0
# Predicted: 8.73083  Actual: 9.0
# Predicted: 7.87918  Actual: 9.0
# Predicted: 8.04721  Actual: 8.0
# Predicted: 8.0854  Actual: 8.0
# Predicted: 7.07103  Actual: 9.0
# Predicted: 7.76286  Actual: 6.0
# Predicted: 7.7636  Actual: 7.0
# Predicted: 7.22966  Actual: 10.0
# Predicted: 7.58696  Actual: 9.0
# Predicted: 7.23271  Actual: 8.0
# Predicted: 7.30645  Actual: 9.0
# Predicted: 8.06753  Actual: 8.0
# Predicted: 7.54297  Actual: 6.0
# Predicted: 7.39218  Actual: 5.0
# Predicted: 7.77413  Actual: 9.0
# Predicted: 7.96314  Actual: 6.0
# Predicted: 7.58658  Actual: 9.0
# Predicted: 7.97352  Actual: 9.0
# Predicted: 7.1262  Actual: 4.0
# Predicted: 7.90675  Actual: 10.0
# Predicted: 7.82035  Actual: 9.0
# Predicted: 8.15183  Actual: 10.0
# Predicted: 7.19789  Actual: 8.0
# Predicted: 7.52882  Actual: 5.0
# Predicted: 7.06179  Actual: 7.0
# Predicted: 7.71123  Actual: 8.0
# Predicted: 7.26986  Actual: 9.0
# Predicted: 7.89821  Actual: 8.0
# Predicted: 7.10341  Actual: 6.0
# Predicted: 7.82149  Actual: 8.0
# Predicted: 7.1819  Actual: 7.0
# Predicted: 7.59901  Actual: 10.0
# Predicted: 7.94698  Actual: 8.0
# Predicted: 7.46433  Actual: 7.0
# Predicted: 7.75788  Actual: 7.0
# Predicted: 8.72648  Actual: 9.0
# Predicted: 8.10266  Actual: 7.0
# Predicted: 7.99602  Actual: 8.0
# Predicted: 7.88797  Actual: 7.0
# Predicted: 7.23979  Actual: 9.0
# Predicted: 7.1822  Actual: 9.0
# Predicted: 7.33199  Actual: 5.0
# Predicted: 8.02649  Actual: 9.0
# Predicted: 7.36062  Actual: 10.0
# Predicted: 8.06861  Actual: 9.0
# Predicted: 7.62825  Actual: 9.0
# Predicted: 8.10511  Actual: 8.0
# Predicted: 7.32372  Actual: 10.0
# Predicted: 8.04456  Actual: 6.0
# Predicted: 7.42853  Actual: 8.0
# Predicted: 8.43409  Actual: 7.0
# Predicted: 7.58869  Actual: 8.0
# Predicted: 8.50973  Actual: 8.0
# Predicted: 7.86164  Actual: 9.0
# Predicted: 7.21967  Actual: 4.0
# Predicted: 7.34556  Actual: 9.0
# Predicted: 7.46005  Actual: 6.0
# Predicted: 8.24686  Actual: 10.0
# Predicted: 7.54935  Actual: 3.0
# Predicted: 7.46117  Actual: 7.0
# Predicted: 8.20411  Actual: 10.0
# Predicted: 7.40932  Actual: 10.0
# Predicted: 8.17319  Actual: 9.0
# Predicted: 7.21618  Actual: 7.0
# Predicted: 8.20269  Actual: 8.0
# Predicted: 7.2752  Actual: 9.0
# Predicted: 7.62479  Actual: 8.0
# Predicted: 7.28195  Actual: 8.0
# Predicted: 7.45603  Actual: 9.0
# Predicted: 7.71695  Actual: 8.0
# Predicted: 7.25011  Actual: 6.0
# Predicted: 7.59407  Actual: 4.0
# Predicted: 7.39993  Actual: 7.0
# Predicted: 7.929  Actual: 10.0
# Predicted: 7.49875  Actual: 4.0
# Predicted: 7.13204  Actual: 7.0
# Predicted: 7.5193  Actual: 8.0
# Predicted: 7.38256  Actual: 7.0
# Predicted: 7.10445  Actual: 6.0
# Predicted: 7.80762  Actual: 10.0
# Predicted: 7.5375  Actual: 9.0
# Predicted: 7.35955  Actual: 7.0
# Predicted: 7.05852  Actual: 6.0
# Predicted: 8.89435  Actual: 7.0
# Predicted: 7.53313  Actual: 5.0
# Predicted: 8.05154  Actual: 9.0
# Predicted: 8.09418  Actual: 10.0
# Predicted: 7.56171  Actual: 10.0
# Predicted: 7.22787  Actual: 8.0
# Predicted: 8.03159  Actual: 7.0
# Predicted: 7.61106  Actual: 7.0
# Predicted: 7.53611  Actual: 10.0
# Predicted: 7.54275  Actual: 9.0
# Predicted: 7.14291  Actual: 7.0
# Predicted: 7.99095  Actual: 10.0
# Predicted: 7.13284  Actual: 8.0
# Predicted: 7.5187  Actual: 5.0
# Predicted: 7.56413  Actual: 7.0
# Predicted: 7.69641  Actual: 6.0
# Predicted: 7.78074  Actual: 8.0
# Predicted: 7.9944  Actual: 8.0
# Predicted: 7.71815  Actual: 7.0
# Predicted: 7.71976  Actual: 7.0
# Predicted: 7.85444  Actual: 9.0
# Predicted: 7.7319  Actual: 8.0
# Predicted: 7.62107  Actual: 10.0
# Predicted: 7.1418  Actual: 8.0
# Predicted: 8.57824  Actual: 8.0
# Predicted: 7.44403  Actual: 6.0
# Predicted: 7.95559  Actual: 9.0
# Predicted: 7.74366  Actual: 9.0
# Predicted: 7.69893  Actual: 9.0
# Predicted: 7.53102  Actual: 6.0
# Predicted: 7.95377  Actual: 9.0
# Predicted: 8.06339  Actual: 6.0
# Predicted: 7.84871  Actual: 8.0
# Predicted: 7.39037  Actual: 9.0
# Predicted: 7.52373  Actual: 7.0
# Predicted: 7.47659  Actual: 9.0
# Predicted: 7.63511  Actual: 6.0
# Predicted: 7.79353  Actual: 7.0
# Predicted: 7.45943  Actual: 8.0
# Predicted: 7.68913  Actual: 5.0
# Predicted: 7.40084  Actual: 6.0
# Predicted: 7.93256  Actual: 8.0
# Predicted: 8.60799  Actual: 7.0
# Predicted: 7.37645  Actual: 7.0
# Predicted: 7.48583  Actual: 10.0
# Predicted: 8.52607  Actual: 9.0
# Predicted: 8.0199  Actual: 7.0
# Predicted: 7.62629  Actual: 7.0
# Predicted: 7.13822  Actual: 5.0
# Predicted: 7.68774  Actual: 7.0
# Predicted: 7.28407  Actual: 6.0
# Predicted: 7.53766  Actual: 8.0
# Predicted: 7.82386  Actual: 8.0
# Predicted: 8.32951  Actual: 10.0
# Predicted: 7.69004  Actual: 6.0
# Predicted: 7.46757  Actual: 3.0
# Predicted: 8.3051  Actual: 7.0
# Predicted: 7.67284  Actual: 10.0
# Predicted: 7.35042  Actual: 9.0
# Predicted: 7.80186  Actual: 8.0
# Predicted: 8.00503  Actual: 8.0
# Predicted: 7.83241  Actual: 9.0
# Predicted: 7.76244  Actual: 7.0
# Predicted: 7.52456  Actual: 8.0
# Predicted: 7.8827  Actual: 9.0
# Predicted: 7.03181  Actual: 7.0
# Predicted: 7.92146  Actual: 8.0
# Predicted: 7.79353  Actual: 8.0
# Predicted: 7.57947  Actual: 7.0
# Predicted: 7.2888  Actual: 5.0
# Predicted: 7.31688  Actual: 6.0
# Predicted: 7.27067  Actual: 9.0
# Predicted: 7.71827  Actual: 7.0
# Predicted: 7.29878  Actual: 7.0
# Predicted: 7.3389  Actual: 7.0
# Predicted: 7.48955  Actual: 8.0
# Predicted: 7.68455  Actual: 8.0
# Predicted: 7.60484  Actual: 10.0
# Predicted: 7.42002  Actual: 6.0
# Predicted: 7.48561  Actual: 9.0
# Predicted: 7.276  Actual: 8.0
# Predicted: 7.53969  Actual: 7.0
# Predicted: 7.48878  Actual: 8.0
# Predicted: 7.70812  Actual: 9.0
# Predicted: 8.23663  Actual: 6.0
# Predicted: 7.36313  Actual: 8.0
# Predicted: 7.92453  Actual: 10.0
# Predicted: 7.25285  Actual: 6.0
# Predicted: 7.58242  Actual: 10.0
# Predicted: 7.35781  Actual: 8.0
# Predicted: 7.9451  Actual: 6.0
# Predicted: 8.17605  Actual: 7.0
# Predicted: 7.17082  Actual: 9.0
# Predicted: 7.52354  Actual: 6.0
# Predicted: 8.10285  Actual: 10.0
# Predicted: 7.40091  Actual: 7.0
# Predicted: 7.08208  Actual: 6.0
# Predicted: 8.11599  Actual: 10.0
# Predicted: 7.88434  Actual: 7.0
# Predicted: 8.08751  Actual: 8.0
# Predicted: 7.37762  Actual: 8.0
# Predicted: 7.43732  Actual: 9.0
# Predicted: 7.67611  Actual: 8.0
# Predicted: 7.4035  Actual: 6.0
# Predicted: 7.72257  Actual: 10.0
# Predicted: 7.81611  Actual: 8.0
# Predicted: 7.94546  Actual: 3.0
# Predicted: 7.79927  Actual: 9.0
# Predicted: 7.3552  Actual: 9.0
# Predicted: 7.81781  Actual: 10.0
# Predicted: 7.40166  Actual: 8.0
# Predicted: 7.1163  Actual: 7.0
# Predicted: 8.33516  Actual: 10.0
# Predicted: 7.90608  Actual: 7.0
# Predicted: 8.0036  Actual: 9.0
# Predicted: 7.27617  Actual: 9.0
# Predicted: 7.15589  Actual: 9.0
# Predicted: 7.27969  Actual: 9.0
# Predicted: 7.73197  Actual: 9.0
# Predicted: 7.98458  Actual: 8.0
# Predicted: 7.50965  Actual: 7.0
# Predicted: 7.39126  Actual: 7.0
# Predicted: 7.57313  Actual: 10.0
# Predicted: 7.46461  Actual: 7.0
# Predicted: 7.84229  Actual: 8.0
# Predicted: 7.10579  Actual: 7.0
# Predicted: 7.36229  Actual: 5.0
# Predicted: 7.57143  Actual: 5.0
# Predicted: 7.49525  Actual: 6.0
# Predicted: 7.8154  Actual: 9.0
# Predicted: 7.56952  Actual: 8.0
# Predicted: 7.93774  Actual: 6.0
# Predicted: 7.42382  Actual: 9.0
# Predicted: 7.34249  Actual: 10.0
# Predicted: 7.29727  Actual: 10.0
# Predicted: 8.17157  Actual: 6.0
# Predicted: 7.20664  Actual: 6.0
# Predicted: 8.19589  Actual: 8.0
# Predicted: 8.21528  Actual: 4.0
# Predicted: 7.38336  Actual: 7.0
# Predicted: 7.68168  Actual: 10.0
# Predicted: 7.05115  Actual: 9.0
# Predicted: 7.74188  Actual: 8.0
# Predicted: 7.26031  Actual: 8.0
# Predicted: 7.49949  Actual: 8.0
# Predicted: 7.81241  Actual: 10.0
# Predicted: 7.10233  Actual: 5.0
# Predicted: 7.71631  Actual: 7.0
# Predicted: 7.71594  Actual: 6.0
# Predicted: 7.32421  Actual: 8.0
# Predicted: 7.36305  Actual: 6.0
# Predicted: 7.10628  Actual: 6.0
# Predicted: 7.24739  Actual: 7.0
# Predicted: 7.91616  Actual: 9.0
# Predicted: 7.66173  Actual: 9.0
# Predicted: 7.46577  Actual: 8.0
# Predicted: 7.28064  Actual: 6.0
# Predicted: 7.94806  Actual: 5.0
# Predicted: 7.7414  Actual: 9.0
# Predicted: 8.32824  Actual: 7.0
# Predicted: 7.64147  Actual: 7.0
# Predicted: 7.50377  Actual: 3.0
# Predicted: 7.51629  Actual: 8.0
# Predicted: 7.92281  Actual: 8.0
# Predicted: 7.42653  Actual: 7.0
# Predicted: 7.29737  Actual: 6.0
# Predicted: 7.77745  Actual: 10.0
# Predicted: 7.36745  Actual: 5.0
# Predicted: 7.18144  Actual: 7.0
# Predicted: 7.58561  Actual: 8.0
# Predicted: 7.67118  Actual: 10.0
# Predicted: 8.33375  Actual: 8.0
# Predicted: 7.44248  Actual: 9.0
# Predicted: 7.40915  Actual: 9.0
# Predicted: 7.45805  Actual: 9.0
# Predicted: 8.01762  Actual: 7.0
# Predicted: 7.6246  Actual: 8.0
# Predicted: 7.23864  Actual: 6.0
# Predicted: 7.76705  Actual: 6.0
# Predicted: 8.06417  Actual: 7.0
# Predicted: 7.56569  Actual: 9.0
# Predicted: 8.27329  Actual: 5.0
# Predicted: 7.39116  Actual: 8.0
# Predicted: 7.56826  Actual: 9.0
# Predicted: 7.46514  Actual: 7.0
# Predicted: 7.14769  Actual: 9.0
# Predicted: 7.9868  Actual: 6.0
# Predicted: 8.46792  Actual: 6.0
# Predicted: 7.31752  Actual: 9.0
# Predicted: 7.39591  Actual: 10.0
# Predicted: 7.10579  Actual: 7.0
# Predicted: 8.17693  Actual: 8.0
# Predicted: 7.23708  Actual: 7.0
# Predicted: 7.89665  Actual: 8.0
# Predicted: 7.40553  Actual: 9.0
# Predicted: 7.65449  Actual: 9.0
# Predicted: 8.06963  Actual: 7.0
# Predicted: 7.19017  Actual: 8.0
# Predicted: 8.09958  Actual: 7.0
# Predicted: 7.41214  Actual: 8.0
# Predicted: 7.68521  Actual: 7.0
# Predicted: 7.33412  Actual: 10.0
# Predicted: 8.01744  Actual: 10.0
# Predicted: 7.31986  Actual: 6.0
# Predicted: 7.80634  Actual: 7.0
# Predicted: 7.54222  Actual: 9.0
# Predicted: 8.23731  Actual: 5.0
# Predicted: 7.94795  Actual: 6.0
# Predicted: 7.4975  Actual: 7.0
# Predicted: 7.45968  Actual: 5.0
# Predicted: 7.33637  Actual: 8.0
# Predicted: 7.71257  Actual: 7.0
# Predicted: 7.58192  Actual: 10.0
# Predicted: 7.70742  Actual: 8.0
# Predicted: 7.98033  Actual: 10.0
# Predicted: 7.23767  Actual: 7.0
# Predicted: 7.7399  Actual: 8.0
# Predicted: 7.5794  Actual: 10.0
# Predicted: 8.4021  Actual: 10.0
# Predicted: 7.63729  Actual: 8.0
# Predicted: 7.96216  Actual: 7.0
# Predicted: 7.86175  Actual: 8.0
# Predicted: 7.91418  Actual: 8.0
# Predicted: 7.56778  Actual: 8.0
# Predicted: 7.27667  Actual: 8.0
# Predicted: 7.60267  Actual: 10.0
# Predicted: 7.99816  Actual: 6.0
# Predicted: 7.48411  Actual: 9.0
# Predicted: 7.13405  Actual: 7.0
# Predicted: 7.42837  Actual: 6.0
# Predicted: 7.17478  Actual: 10.0
# Predicted: 7.75174  Actual: 9.0
# Predicted: 7.76285  Actual: 8.0
# Predicted: 7.15841  Actual: 10.0
# Predicted: 7.68566  Actual: 8.0
# Predicted: 7.23131  Actual: 10.0
# Predicted: 7.80775  Actual: 10.0
# Predicted: 7.88039  Actual: 8.0
# Predicted: 7.72039  Actual: 6.0
# Predicted: 7.75708  Actual: 7.0
# Predicted: 7.24035  Actual: 9.0
# Predicted: 7.45714  Actual: 6.0
# Predicted: 7.7615  Actual: 6.0
# Predicted: 7.20505  Actual: 6.0
# Predicted: 7.79772  Actual: 5.0
# Predicted: 7.5626  Actual: 8.0
# Predicted: 7.38462  Actual: 7.0
# Predicted: 7.77804  Actual: 8.0
# Predicted: 7.99552  Actual: 6.0
# Predicted: 7.76874  Actual: 7.0
# Predicted: 7.98687  Actual: 10.0
# Predicted: 7.50426  Actual: 7.0
# Predicted: 7.5236  Actual: 10.0
# Predicted: 8.07553  Actual: 9.0
# Predicted: 7.37057  Actual: 8.0
# Predicted: 8.50482  Actual: 10.0
# Predicted: 7.63508  Actual: 7.0
# Predicted: 7.58691  Actual: 7.0
# Predicted: 7.0694  Actual: 6.0
# Predicted: 7.53082  Actual: 5.0
# Predicted: 7.58086  Actual: 8.0
# Predicted: 7.52978  Actual: 7.0
# Predicted: 7.7886  Actual: 5.0
# Predicted: 8.02936  Actual: 7.0
# Predicted: 7.79608  Actual: 9.0
# Predicted: 7.39162  Actual: 4.0
# Predicted: 7.54497  Actual: 10.0
# Predicted: 8.3488  Actual: 7.0
# Predicted: 7.12474  Actual: 8.0
# Predicted: 7.86025  Actual: 10.0
# Predicted: 7.7011  Actual: 7.0
# Predicted: 7.77968  Actual: 8.0
# Predicted: 7.36085  Actual: 9.0
# Predicted: 7.61516  Actual: 10.0
# Predicted: 7.25203  Actual: 8.0
# Predicted: 7.49735  Actual: 8.0
# Predicted: 7.61103  Actual: 9.0
# Predicted: 7.76685  Actual: 9.0
# Predicted: 7.67914  Actual: 8.0
# Predicted: 7.34311  Actual: 10.0
# Predicted: 7.50887  Actual: 7.0
# Predicted: 7.91475  Actual: 8.0
# Predicted: 7.4098  Actual: 5.0
# Predicted: 7.69266  Actual: 9.0
# Predicted: 7.23765  Actual: 9.0
# Predicted: 8.17854  Actual: 9.0
# Predicted: 7.60171  Actual: 10.0
# Predicted: 8.12686  Actual: 8.0
# Predicted: 7.92764  Actual: 10.0
# Predicted: 7.54063  Actual: 10.0
# Predicted: 8.27706  Actual: 9.0
# Predicted: 7.50979  Actual: 5.0
# Predicted: 7.3449  Actual: 3.0
# Predicted: 7.21537  Actual: 5.0
# Predicted: 7.77783  Actual: 8.0
# Predicted: 8.10407  Actual: 10.0
# Predicted: 8.17244  Actual: 4.0
# Predicted: 7.74722  Actual: 8.0
# Predicted: 7.36025  Actual: 8.0
# Predicted: 7.60487  Actual: 9.0
# Predicted: 7.81252  Actual: 8.0
# Predicted: 7.10347  Actual: 6.0
# Predicted: 8.05069  Actual: 10.0
# Predicted: 7.56229  Actual: 7.0
# Predicted: 8.00605  Actual: 7.0
# Predicted: 7.12442  Actual: 5.0
# Predicted: 7.3757  Actual: 9.0
# Predicted: 7.39501  Actual: 5.0
# Predicted: 7.49217  Actual: 7.0
# Predicted: 7.13822  Actual: 8.0
# Predicted: 7.07774  Actual: 3.0
# Predicted: 7.66801  Actual: 5.0
# Predicted: 7.33478  Actual: 10.0
# Predicted: 8.21304  Actual: 10.0
# Predicted: 7.71879  Actual: 9.0
# Predicted: 7.87282  Actual: 7.0
# Predicted: 7.27753  Actual: 8.0
# Predicted: 8.484  Actual: 9.0
# Predicted: 7.44735  Actual: 10.0
# Predicted: 7.54423  Actual: 9.0
# Predicted: 7.92086  Actual: 8.0
# Predicted: 7.51281  Actual: 7.0
# Predicted: 7.30592  Actual: 8.0
# Predicted: 7.57312  Actual: 9.0
# Predicted: 7.67577  Actual: 7.0
# Predicted: 8.16132  Actual: 8.0
# Predicted: 7.32587  Actual: 8.0
# Predicted: 8.41687  Actual: 9.0
# Predicted: 7.66397  Actual: 7.0
# Predicted: 7.29365  Actual: 8.0
# Predicted: 7.65774  Actual: 7.0
# Predicted: 7.10445  Actual: 9.0
# Predicted: 7.6166  Actual: 7.0
# Predicted: 7.56733  Actual: 8.0
# Predicted: 7.78402  Actual: 10.0
# Predicted: 7.77692  Actual: 8.0
# Predicted: 7.71461  Actual: 7.0
# Predicted: 7.35969  Actual: 6.0
# Predicted: 8.43899  Actual: 10.0
# Predicted: 7.37613  Actual: 7.0
# Predicted: 7.70992  Actual: 7.0
# Predicted: 7.73174  Actual: 8.0
# Predicted: 7.10982  Actual: 8.0
# Predicted: 7.07103  Actual: 6.0
# Predicted: 7.77949  Actual: 9.0
# Predicted: 7.84688  Actual: 8.0
# Predicted: 7.22031  Actual: 7.0
# Predicted: 7.30143  Actual: 7.0
# Predicted: 8.61883  Actual: 6.0
# Predicted: 7.35517  Actual: 8.0
# Predicted: 7.79453  Actual: 8.0
# Predicted: 7.46011  Actual: 3.0
# Predicted: 7.49719  Actual: 9.0
# Predicted: 7.78002  Actual: 9.0
# Predicted: 8.0071  Actual: 8.0
# Predicted: 7.68393  Actual: 9.0
# Predicted: 8.01355  Actual: 10.0
# Predicted: 7.51103  Actual: 7.0
# Predicted: 7.53102  Actual: 8.0
# Predicted: 7.9362  Actual: 9.0
# Predicted: 7.38413  Actual: 7.0
# Predicted: 8.50107  Actual: 9.0
# Predicted: 7.33996  Actual: 7.0
# Predicted: 8.15647  Actual: 8.0
# Predicted: 7.73162  Actual: 10.0
# Predicted: 7.59953  Actual: 8.0
# Predicted: 7.07157  Actual: 8.0
# Predicted: 7.31952  Actual: 10.0
# Predicted: 7.73723  Actual: 5.0
# Predicted: 7.12946  Actual: 7.0
# Predicted: 8.31812  Actual: 8.0
# Predicted: 7.71138  Actual: 9.0
# Predicted: 7.57515  Actual: 10.0
# Predicted: 7.83068  Actual: 9.0
# Predicted: 7.07035  Actual: 10.0
# Predicted: 7.6639  Actual: 10.0
# Predicted: 7.86074  Actual: 6.0
# Predicted: 7.5013  Actual: 7.0
# Predicted: 7.44748  Actual: 6.0
# Predicted: 8.18604  Actual: 9.0
# Predicted: 7.53371  Actual: 7.0
# Predicted: 7.41276  Actual: 10.0
# Predicted: 7.37753  Actual: 8.0
# Predicted: 7.50362  Actual: 9.0
# Predicted: 8.10678  Actual: 7.0
# Predicted: 7.43658  Actual: 7.0
# Predicted: 7.44024  Actual: 8.0
# Predicted: 7.46756  Actual: 4.0
# Predicted: 7.14926  Actual: 6.0
# Predicted: 7.95768  Actual: 10.0
# Predicted: 8.22563  Actual: 9.0
# Predicted: 7.60472  Actual: 3.0
# Predicted: 7.56714  Actual: 7.0
# Predicted: 7.90063  Actual: 10.0
# Predicted: 7.93905  Actual: 8.0
# Predicted: 7.37976  Actual: 7.0
# Predicted: 7.36086  Actual: 10.0
# Predicted: 7.35779  Actual: 8.0
# Predicted: 7.66416  Actual: 8.0
# Predicted: 7.45375  Actual: 9.0
# Predicted: 7.78769  Actual: 10.0
# Predicted: 7.1116  Actual: 6.0
# Predicted: 7.64865  Actual: 8.0
# Predicted: 7.28669  Actual: 8.0
# Predicted: 7.54299  Actual: 6.0
# Predicted: 7.68394  Actual: 6.0
# Predicted: 8.28941  Actual: 8.0
# ...
# Predicted: 7.92383  Actual: 8.0
# Predicted: 7.30542  Actual: 8.0
# Predicted: 7.70033  Actual: 6.0
# Predicted: 8.0127  Actual: 10.0
# Predicted: 7.94791  Actual: 7.0
# Predicted: 7.20505  Actual: 7.0
# Predicted: 8.02828  Actual: 9.0
# Predicted: 7.25589  Actual: 9.0
# Predicted: 7.82444  Actual: 8.0
# Predicted: 7.92519  Actual: 8.0
# Predicted: 7.40189  Actual: 7.0
# Predicted: 7.85526  Actual: 9.0
# Predicted: 7.18171  Actual: 8.0
# Predicted: 7.48844  Actual: 6.0
# Predicted: 7.24406  Actual: 8.0
# Predicted: 8.15098  Actual: 4.0
# Predicted: 7.69945  Actual: 10.0
# Predicted: 7.77597  Actual: 8.0
# Predicted: 7.41274  Actual: 8.0
# Predicted: 7.36095  Actual: 8.0
# Predicted: 8.19803  Actual: 9.0
# Predicted: 7.45798  Actual: 6.0
# Predicted: 7.25673  Actual: 5.0
# Predicted: 7.7339  Actual: 8.0
# Predicted: 8.23409  Actual: 9.0
# Predicted: 8.2659  Actual: 7.0
# Predicted: 7.46877  Actual: 9.0
# Predicted: 7.46894  Actual: 8.0
# Predicted: 8.05794  Actual: 8.0
# Predicted: 7.50849  Actual: 7.0
# Predicted: 7.88633  Actual: 8.0
# Predicted: 7.87468  Actual: 8.0
# Predicted: 7.83915  Actual: 8.0
# Predicted: 7.80538  Actual: 7.0
# Predicted: 8.21147  Actual: 10.0
# Predicted: 7.68753  Actual: 6.0
# Predicted: 7.80042  Actual: 7.0
# Predicted: 8.0806  Actual: 7.0
# Predicted: 7.11384  Actual: 7.0
# Predicted: 7.46417  Actual: 5.0
# Predicted: 7.41856  Actual: 6.0
# Predicted: 7.49514  Actual: 8.0
# Predicted: 7.49691  Actual: 7.0
# Predicted: 7.79459  Actual: 7.0
# Predicted: 7.35561  Actual: 8.0
# Predicted: 7.92813  Actual: 8.0
# Predicted: 7.44702  Actual: 6.0
# Predicted: 7.84766  Actual: 8.0
# Predicted: 7.56356  Actual: 10.0
# Predicted: 7.28667  Actual: 7.0
# Predicted: 8.09481  Actual: 7.0
# Predicted: 7.29212  Actual: 7.0
# Predicted: 7.76465  Actual: 8.0
# Predicted: 7.23765  Actual: 10.0
# Predicted: 7.59108  Actual: 6.0
# Predicted: 7.89172  Actual: 9.0
# Predicted: 7.20052  Actual: 8.0
# Predicted: 7.58311  Actual: 8.0
# Predicted: 7.71591  Actual: 9.0
# Predicted: 8.11011  Actual: 9.0
# Predicted: 7.85428  Actual: 7.0
# Predicted: 7.31568  Actual: 7.0
# Predicted: 7.09646  Actual: 8.0
# Predicted: 7.57056  Actual: 8.0
# Predicted: 7.6333  Actual: 4.0
# Predicted: 8.07067  Actual: 8.0
# Predicted: 7.83102  Actual: 10.0
# Predicted: 7.55322  Actual: 7.0
# Predicted: 7.42579  Actual: 9.0
# Predicted: 7.75055  Actual: 8.0
# Predicted: 7.90409  Actual: 8.0
# Predicted: 7.64458  Actual: 7.0
# Predicted: 7.43823  Actual: 8.0
# Predicted: 7.52866  Actual: 6.0
# Predicted: 7.61195  Actual: 9.0
# Predicted: 7.30643  Actual: 8.0
# Predicted: 8.0326  Actual: 10.0
# Predicted: 8.02353  Actual: 7.0
# Predicted: 8.06039  Actual: 8.0
# Predicted: 7.55678  Actual: 8.0
# Predicted: 7.33772  Actual: 8.0
# Predicted: 7.11744  Actual: 7.0
# Predicted: 7.87543  Actual: 8.0
# Predicted: 8.40101  Actual: 7.0
# Predicted: 7.43581  Actual: 8.0
# Predicted: 7.50594  Actual: 7.0
# Predicted: 7.64292  Actual: 7.0
# Predicted: 7.44011  Actual: 8.0
# Predicted: 7.57189  Actual: 10.0
# Predicted: 7.07488  Actual: 7.0
# Predicted: 7.89548  Actual: 9.0
# Predicted: 7.34602  Actual: 9.0
# Predicted: 7.66424  Actual: 9.0
# Predicted: 7.27868  Actual: 8.0
# Predicted: 7.19236  Actual: 7.0
# Predicted: 7.06617  Actual: 2.0
# Predicted: 7.11157  Actual: 5.0
# Predicted: 7.1214  Actual: 7.0
# Predicted: 7.18579  Actual: 8.0
# Predicted: 7.83484  Actual: 6.0
# Predicted: 7.76467  Actual: 8.0
# Predicted: 7.4395  Actual: 4.0
# Predicted: 7.34053  Actual: 9.0
# Predicted: 7.12308  Actual: 6.0
# Predicted: 7.53945  Actual: 9.0
# Predicted: 8.35294  Actual: 6.0
# Predicted: 7.65771  Actual: 9.0
# Predicted: 7.67019  Actual: 8.0
# Predicted: 7.8453  Actual: 9.0
# Predicted: 7.76606  Actual: 10.0
# Predicted: 7.81185  Actual: 7.0
# Predicted: 7.56064  Actual: 7.0
# Predicted: 7.90841  Actual: 8.0
# Predicted: 7.37052  Actual: 7.0
# Predicted: 7.68747  Actual: 8.0
# Predicted: 7.38949  Actual: 7.0
# Predicted: 7.09952  Actual: 2.0
# Predicted: 7.70318  Actual: 7.0
# Predicted: 7.18286  Actual: 8.0
# Predicted: 7.91317  Actual: 8.0
# Predicted: 7.48919  Actual: 8.0
# Predicted: 7.92893  Actual: 10.0
# Predicted: 8.54493  Actual: 10.0
# Predicted: 7.18546  Actual: 10.0
# Predicted: 8.11761  Actual: 10.0
# Predicted: 7.67921  Actual: 8.0
# Predicted: 7.93857  Actual: 9.0
# Predicted: 7.62264  Actual: 10.0
# Predicted: 7.67293  Actual: 10.0
# Predicted: 8.43417  Actual: 7.0
# Predicted: 7.63529  Actual: 7.0
# Predicted: 8.21864  Actual: 10.0
# Predicted: 7.43676  Actual: 4.0
# Predicted: 7.7079  Actual: 5.0
# Predicted: 7.37995  Actual: 9.0
# Predicted: 7.36326  Actual: 4.0
# Predicted: 7.47397  Actual: 7.0
# Predicted: 7.49691  Actual: 7.0
# Predicted: 7.89013  Actual: 8.0
# Predicted: 7.53028  Actual: 9.0
# Predicted: 7.88496  Actual: 9.0
# Predicted: 8.41723  Actual: 10.0
# Predicted: 7.91552  Actual: 6.0
# Predicted: 7.08293  Actual: 6.0
# Predicted: 8.34602  Actual: 9.0
# Predicted: 7.39383  Actual: 8.0
# Predicted: 7.28191  Actual: 9.0
# Predicted: 7.33676  Actual: 3.0
# Predicted: 7.83521  Actual: 7.0
# Predicted: 7.3941  Actual: 4.0
# Predicted: 7.5867  Actual: 10.0
# Predicted: 8.42197  Actual: 7.0
# Predicted: 7.09977  Actual: 7.0
# Predicted: 7.21537  Actual: 8.0
# Predicted: 7.32587  Actual: 7.0
# Predicted: 7.64134  Actual: 8.0
# Predicted: 7.44282  Actual: 9.0
# Predicted: 7.60783  Actual: 4.0
# Predicted: 7.86503  Actual: 8.0
# Predicted: 7.20484  Actual: 7.0
# Predicted: 8.32564  Actual: 9.0
# Predicted: 7.74192  Actual: 5.0
# Predicted: 7.60683  Actual: 8.0
# Predicted: 7.6589  Actual: 8.0
# Predicted: 7.31179  Actual: 7.0
# Predicted: 8.32874  Actual: 9.0
# Predicted: 7.49493  Actual: 6.0
# Predicted: 7.78415  Actual: 6.0
# Predicted: 7.33689  Actual: 6.0
# Predicted: 7.84337  Actual: 10.0
# Predicted: 7.55912  Actual: 7.0
# Predicted: 7.2489  Actual: 8.0
# Predicted: 7.33651  Actual: 6.0
# Predicted: 7.88916  Actual: 10.0
# Predicted: 7.20317  Actual: 7.0
# Predicted: 7.79055  Actual: 7.0
# Predicted: 7.72643  Actual: 9.0
# Predicted: 8.03549  Actual: 7.0
# Predicted: 7.86146  Actual: 8.0
# Predicted: 8.15416  Actual: 9.0
# Predicted: 7.88811  Actual: 10.0
# Predicted: 7.93268  Actual: 8.0
# Predicted: 8.26393  Actual: 8.0
# Predicted: 7.13663  Actual: 8.0
# Predicted: 7.54612  Actual: 6.0
# Predicted: 7.73264  Actual: 9.0
# Predicted: 7.64379  Actual: 6.0
# Predicted: 7.52078  Actual: 7.0
# Predicted: 7.14382  Actual: 7.0
# Predicted: 7.29446  Actual: 10.0
# Predicted: 7.42094  Actual: 7.0
# Predicted: 7.71035  Actual: 7.0
# Predicted: 7.58608  Actual: 9.0
# Predicted: 7.49848  Actual: 8.0
# Predicted: 7.42179  Actual: 9.0
# Predicted: 7.60154  Actual: 7.0
# Predicted: 7.26154  Actual: 8.0
# Predicted: 7.94647  Actual: 8.0
# Predicted: 7.57356  Actual: 8.0
# Predicted: 7.85618  Actual: 7.0
# Predicted: 7.47793  Actual: 6.0
# Predicted: 7.74093  Actual: 6.0
# Predicted: 7.45888  Actual: 10.0
# Predicted: 7.22233  Actual: 7.0
# Predicted: 7.52486  Actual: 9.0
# Predicted: 8.13734  Actual: 8.0
# Predicted: 7.42072  Actual: 6.0
# Predicted: 7.50938  Actual: 9.0
# Predicted: 7.29238  Actual: 8.0
# Predicted: 7.0527  Actual: 7.0
# Predicted: 7.25368  Actual: 4.0
# Predicted: 7.13222  Actual: 8.0
# Predicted: 7.88303  Actual: 8.0
# Predicted: 8.09422  Actual: 10.0
# Predicted: 7.11233  Actual: 7.0
# Predicted: 7.50034  Actual: 8.0
# Predicted: 7.4803  Actual: 2.0
# Predicted: 8.01387  Actual: 8.0
# Predicted: 7.61035  Actual: 8.0
# Predicted: 7.94973  Actual: 8.0
# Predicted: 7.30238  Actual: 7.0
# Predicted: 7.42437  Actual: 6.0
# Predicted: 7.93926  Actual: 9.0
# Predicted: 7.84495  Actual: 9.0
# Predicted: 7.5549  Actual: 10.0
# Predicted: 8.11105  Actual: 10.0
# Predicted: 7.70984  Actual: 10.0
# Predicted: 7.40954  Actual: 6.0
# Predicted: 7.42503  Actual: 5.0
# Predicted: 7.66899  Actual: 6.0
# Predicted: 7.28454  Actual: 8.0
# Predicted: 7.4258  Actual: 7.0
# Predicted: 7.73388  Actual: 8.0
# Predicted: 7.78191  Actual: 7.0
# Predicted: 7.49381  Actual: 10.0
# Predicted: 7.73445  Actual: 9.0
# Predicted: 7.79536  Actual: 7.0
# Predicted: 7.63343  Actual: 8.0
# Predicted: 7.1819  Actual: 7.0
# Predicted: 7.82438  Actual: 6.0
# Predicted: 7.43368  Actual: 7.0
# Predicted: 7.71063  Actual: 8.0
# Predicted: 7.48971  Actual: 9.0
# Predicted: 7.24482  Actual: 7.0
# Predicted: 7.24617  Actual: 7.0
# Predicted: 7.80239  Actual: 8.0
# Predicted: 7.28473  Actual: 6.0
# Predicted: 7.54255  Actual: 6.0
# Predicted: 7.83799  Actual: 9.0
# Predicted: 7.82706  Actual: 8.0
# Predicted: 7.91168  Actual: 8.0
# Predicted: 7.42592  Actual: 6.0
# Predicted: 7.34802  Actual: 8.0
# Predicted: 7.8479  Actual: 8.0
# Predicted: 8.56001  Actual: 8.0
# Predicted: 7.20504  Actual: 7.0
# Predicted: 7.35624  Actual: 9.0
# Predicted: 7.97647  Actual: 9.0
# Predicted: 8.01295  Actual: 8.0
# Predicted: 7.2747  Actual: 8.0
# Predicted: 7.68892  Actual: 10.0
# Predicted: 8.05595  Actual: 9.0
# Predicted: 7.50299  Actual: 7.0
# Predicted: 7.86052  Actual: 6.0
# Predicted: 8.00559  Actual: 6.0
# Predicted: 7.32253  Actual: 5.0
# Predicted: 7.49226  Actual: 6.0
# Predicted: 7.59685  Actual: 8.0
# Predicted: 7.64711  Actual: 5.0
# Predicted: 7.82052  Actual: 9.0
# Predicted: 7.23901  Actual: 9.0
# Predicted: 7.56368  Actual: 9.0
# Predicted: 7.94766  Actual: 7.0
# Predicted: 8.23847  Actual: 7.0
# Predicted: 7.84033  Actual: 8.0
# Predicted: 7.33439  Actual: 6.0
# Predicted: 7.78422  Actual: 6.0
# Predicted: 7.95015  Actual: 7.0
# Predicted: 7.60075  Actual: 6.0
# Predicted: 7.47833  Actual: 10.0
# Predicted: 7.40281  Actual: 6.0
# Predicted: 7.1339  Actual: 5.0
# Predicted: 8.07589  Actual: 10.0
# Predicted: 7.46252  Actual: 9.0
# Predicted: 7.40328  Actual: 8.0
# Predicted: 7.65439  Actual: 6.0
# Predicted: 7.22218  Actual: 10.0
# Predicted: 8.03537  Actual: 8.0
# Predicted: 7.23206  Actual: 8.0
# Predicted: 7.48836  Actual: 7.0
# Predicted: 8.08366  Actual: 9.0
# Predicted: 7.69056  Actual: 10.0
# Predicted: 7.33445  Actual: 7.0
# Predicted: 7.21628  Actual: 7.0
# Predicted: 7.4719  Actual: 1.0
# Predicted: 7.44976  Actual: 7.0
# Predicted: 7.66377  Actual: 8.0
# Predicted: 7.90389  Actual: 7.0
# Predicted: 7.53367  Actual: 4.0
# Predicted: 7.37915  Actual: 10.0
# Predicted: 7.32894  Actual: 7.0
# Predicted: 7.72312  Actual: 8.0
# Predicted: 7.64261  Actual: 8.0
# Predicted: 7.46955  Actual: 8.0
# Predicted: 7.63957  Actual: 8.0
# Predicted: 7.32178  Actual: 9.0
# Predicted: 8.02675  Actual: 10.0
# Predicted: 7.18869  Actual: 4.0
# Predicted: 7.60341  Actual: 8.0
# Predicted: 7.82963  Actual: 8.0
# Predicted: 7.24926  Actual: 8.0
# Predicted: 7.87793  Actual: 7.0
# Predicted: 7.81569  Actual: 9.0
# Predicted: 7.5705  Actual: 7.0
# Predicted: 7.41286  Actual: 7.0
# Predicted: 7.75885  Actual: 9.0
# Predicted: 7.40118  Actual: 6.0
# Predicted: 7.12464  Actual: 8.0
# Predicted: 7.70332  Actual: 5.0
# Predicted: 7.34578  Actual: 8.0
# Predicted: 8.004  Actual: 7.0
# Predicted: 7.8362  Actual: 9.0
# Predicted: 7.49439  Actual: 7.0
# Predicted: 7.77848  Actual: 7.0
# Predicted: 7.13383  Actual: 9.0
# Predicted: 7.02921  Actual: 10.0
# Predicted: 7.18553  Actual: 6.0
# Predicted: 7.58102  Actual: 9.0
# Predicted: 7.68126  Actual: 8.0
# Predicted: 7.70811  Actual: 9.0
# Predicted: 7.699  Actual: 7.0
# Predicted: 7.92408  Actual: 10.0
# Predicted: 7.0694  Actual: 8.0
# Predicted: 8.36569  Actual: 9.0
# Predicted: 7.29184  Actual: 6.0
# Predicted: 7.01921  Actual: 8.0
# Predicted: 7.72179  Actual: 9.0
# Predicted: 7.46011  Actual: 1.0
# Predicted: 7.13728  Actual: 9.0
# Predicted: 7.27385  Actual: 7.0
# Predicted: 7.84274  Actual: 8.0
# Predicted: 7.52846  Actual: 7.0
# Predicted: 7.32875  Actual: 10.0
# Predicted: 7.4954  Actual: 7.0
# Predicted: 7.3095  Actual: 10.0
# Predicted: 8.04826  Actual: 8.0
# Predicted: 7.74602  Actual: 9.0
# Predicted: 7.18251  Actual: 7.0
# Predicted: 7.56453  Actual: 7.0
# Predicted: 8.13215  Actual: 9.0
# Predicted: 7.66394  Actual: 8.0
# Predicted: 8.09868  Actual: 7.0
# Predicted: 7.95071  Actual: 9.0
# Predicted: 7.44569  Actual: 6.0
# Predicted: 7.39301  Actual: 8.0
# Predicted: 7.67842  Actual: 8.0
# Predicted: 7.89045  Actual: 7.0
# Predicted: 7.49589  Actual: 10.0
# Predicted: 7.38291  Actual: 10.0
# Predicted: 7.62793  Actual: 7.0
# Predicted: 7.54199  Actual: 8.0
# Predicted: 7.16232  Actual: 8.0
# Predicted: 8.67132  Actual: 8.0
# Predicted: 7.97791  Actual: 8.0
# Predicted: 7.70755  Actual: 7.0
# Predicted: 7.17522  Actual: 10.0
# Predicted: 7.52613  Actual: 9.0
# Predicted: 7.53406  Actual: 9.0
# Predicted: 7.64226  Actual: 7.0
# Predicted: 7.69556  Actual: 10.0
# Predicted: 7.69456  Actual: 9.0
# Predicted: 7.47011  Actual: 8.0
# Predicted: 7.07103  Actual: 7.0
# Predicted: 7.56184  Actual: 10.0
# Predicted: 7.10233  Actual: 7.0
# Predicted: 7.9249  Actual: 8.0
# Predicted: 7.65478  Actual: 8.0
# Predicted: 7.46486  Actual: 8.0
# Predicted: 7.73421  Actual: 7.0
# Predicted: 7.82394  Actual: 7.0
# Predicted: 7.58713  Actual: 5.0
# Predicted: 7.2989  Actual: 7.0
# Predicted: 7.53889  Actual: 10.0
# Predicted: 7.33986  Actual: 7.0
# Predicted: 7.16391  Actual: 8.0
# Predicted: 7.93036  Actual: 8.0
# Predicted: 8.16056  Actual: 9.0
# Predicted: 7.0316  Actual: 3.0
# Predicted: 7.43258  Actual: 10.0
# Predicted: 7.14334  Actual: 9.0
# Predicted: 8.07199  Actual: 7.0
# Predicted: 7.40051  Actual: 3.0
# Predicted: 7.84186  Actual: 8.0
# Predicted: 7.5935  Actual: 8.0
# Predicted: 7.43235  Actual: 7.0
# Predicted: 8.42983  Actual: 6.0
# Predicted: 7.91513  Actual: 7.0
# Predicted: 7.38602  Actual: 6.0
# Predicted: 7.24415  Actual: 8.0
# Predicted: 7.35023  Actual: 8.0
# Predicted: 7.60863  Actual: 6.0
# Predicted: 7.3646  Actual: 9.0
# Predicted: 7.37898  Actual: 10.0
# Predicted: 7.59554  Actual: 8.0
# Predicted: 8.44641  Actual: 7.0
# Predicted: 8.12562  Actual: 4.0
# Predicted: 7.62798  Actual: 8.0
# Predicted: 7.46832  Actual: 7.0
# Predicted: 7.43602  Actual: 8.0
# Predicted: 7.31295  Actual: 8.0
# Predicted: 7.67377  Actual: 8.0
# Predicted: 8.30654  Actual: 7.0
# Predicted: 7.62341  Actual: 6.0
# Predicted: 7.418  Actual: 7.0
# Predicted: 7.28954  Actual: 6.0
# Predicted: 7.64112  Actual: 8.0
# Predicted: 7.52667  Actual: 9.0
# Predicted: 7.34921  Actual: 8.0
# Predicted: 7.8973  Actual: 8.0
# Predicted: 7.53079  Actual: 10.0
# Predicted: 7.53627  Actual: 8.0
# Predicted: 7.9512  Actual: 8.0
# Predicted: 7.11057  Actual: 7.0
# Predicted: 7.56989  Actual: 8.0
# Predicted: 7.3664  Actual: 8.0
# Predicted: 8.1153  Actual: 8.0
# Predicted: 7.38145  Actual: 6.0
# Predicted: 7.51403  Actual: 8.0
# Predicted: 7.93246  Actual: 8.0
# Predicted: 7.65782  Actual: 6.0
# Predicted: 7.17041  Actual: 3.0
# Predicted: 8.09732  Actual: 8.0
# Predicted: 7.8122  Actual: 9.0
# Predicted: 7.29804  Actual: 7.0
# Predicted: 7.20379  Actual: 7.0
# Predicted: 7.87676  Actual: 8.0
# Predicted: 7.85702  Actual: 10.0
# Predicted: 8.62182  Actual: 10.0
# Predicted: 7.83521  Actual: 10.0
# Predicted: 8.03786  Actual: 9.0
# Predicted: 8.04005  Actual: 9.0
# Predicted: 7.46787  Actual: 7.0
# Predicted: 8.04801  Actual: 9.0
# Predicted: 7.36901  Actual: 9.0
# Predicted: 8.24878  Actual: 6.0
# Predicted: 7.44226  Actual: 10.0
# Predicted: 7.33939  Actual: 7.0
# Predicted: 8.22948  Actual: 10.0
# Predicted: 7.1712  Actual: 9.0
# Predicted: 7.5787  Actual: 9.0
# Predicted: 7.52171  Actual: 8.0
# Predicted: 7.67672  Actual: 9.0
# Predicted: 7.87429  Actual: 9.0
# Predicted: 7.90895  Actual: 9.0
# Predicted: 7.39883  Actual: 9.0
# Predicted: 7.0527  Actual: 8.0
# Predicted: 7.6621  Actual: 8.0
# Predicted: 7.36449  Actual: 8.0
# Predicted: 8.00634  Actual: 9.0
# Predicted: 7.06747  Actual: 8.0
# Predicted: 7.90482  Actual: 6.0
# Predicted: 7.22999  Actual: 6.0
# Predicted: 7.66954  Actual: 8.0
# Predicted: 7.39744  Actual: 10.0
# Predicted: 7.46772  Actual: 8.0
# Predicted: 7.26367  Actual: 5.0
# Predicted: 7.05965  Actual: 5.0
# Predicted: 7.99916  Actual: 7.0
# Predicted: 7.41235  Actual: 7.0
# Predicted: 8.06223  Actual: 10.0
# Predicted: 7.51772  Actual: 8.0
# Predicted: 7.42702  Actual: 8.0
# Predicted: 7.50818  Actual: 7.0
# Predicted: 7.24734  Actual: 9.0
# Predicted: 7.13805  Actual: 9.0
# Predicted: 7.25505  Actual: 9.0
# Predicted: 7.66312  Actual: 10.0
# Predicted: 7.85632  Actual: 9.0
# Predicted: 7.99474  Actual: 9.0
# Predicted: 7.9829  Actual: 7.0
# Predicted: 7.11233  Actual: 6.0
# Predicted: 8.44284  Actual: 9.0
# Predicted: 7.28564  Actual: 7.0
# Predicted: 7.72121  Actual: 8.0
# Predicted: 7.40886  Actual: 8.0
# Predicted: 7.64887  Actual: 10.0
# Predicted: 7.45376  Actual: 10.0
# Predicted: 7.91678  Actual: 7.0
# Predicted: 7.54574  Actual: 8.0
# Predicted: 7.14757  Actual: 8.0
# Predicted: 7.78067  Actual: 9.0
# Predicted: 7.06497  Actual: 5.0
# Predicted: 8.11283  Actual: 9.0
# Predicted: 7.97064  Actual: 6.0
# Predicted: 8.12156  Actual: 7.0
# Predicted: 7.65468  Actual: 9.0
# Predicted: 7.58944  Actual: 8.0
# Predicted: 7.52438  Actual: 9.0
# Predicted: 7.40469  Actual: 8.0
